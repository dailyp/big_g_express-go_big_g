# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries-and-Datasets" data-toc-modified-id="Libraries-and-Datasets-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries and Datasets</a></span></li><li><span><a href="#Looking-at-engine_faults" data-toc-modified-id="Looking-at-engine_faults-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Looking at <code>engine_faults</code></a></span><ul class="toc-item"><li><span><a href="#Provided-Data-Dictionary-for-engine_faults" data-toc-modified-id="Provided-Data-Dictionary-for-engine_faults-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Provided Data Dictionary for <code>engine_faults</code></a></span></li><li><span><a href="#Data-Cleanups-engine_Faults" data-toc-modified-id="Data-Cleanups-engine_Faults-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data Cleanups <code>engine_Faults</code></a></span></li><li><span><a href="#Final-engine_faults-before-merge" data-toc-modified-id="Final-engine_faults-before-merge-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Final <code>engine_faults</code> before merge</a></span></li></ul></li><li><span><a href="#Looking-at-diagnostics" data-toc-modified-id="Looking-at-diagnostics-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Looking at <code>diagnostics</code></a></span><ul class="toc-item"><li><span><a href="#Data-Cleanups:-diagnostics" data-toc-modified-id="Data-Cleanups:-diagnostics-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Data Cleanups: <code>diagnostics</code></a></span></li><li><span><a href="#Final-diagnostics-before-merge" data-toc-modified-id="Final-diagnostics-before-merge-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Final <code>diagnostics</code> before merge</a></span></li></ul></li><li><span><a href="#Merging-engine_faults-and-diagnostics" data-toc-modified-id="Merging-engine_faults-and-diagnostics-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Merging <code>engine_faults</code> and <code>diagnostics</code></a></span><ul class="toc-item"><li><span><a href="#Additional-Data-Cleanups-Post-Merging" data-toc-modified-id="Additional-Data-Cleanups-Post-Merging-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Additional Data Cleanups Post-Merging</a></span><ul class="toc-item"><li><span><a href="#Remove-faults-where-equipmentID-has-more-than-5-characters" data-toc-modified-id="Remove-faults-where-equipmentID-has-more-than-5-characters-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Remove faults where equipmentID has more than 5 characters</a></span></li><li><span><a href="#Remove-faults-where-active-is-set-to-False" data-toc-modified-id="Remove-faults-where-active-is-set-to-False-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Remove faults where <code>active</code> is set to <code>False</code></a></span></li><li><span><a href="#Remove-faults-in-the-vicinity-of-service-location" data-toc-modified-id="Remove-faults-in-the-vicinity-of-service-location-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Remove faults in the vicinity of service location</a></span><ul class="toc-item"><li><span><a href="#Solution-1:-Use-Decimal-Degrees-Precision-of-Coordinates" data-toc-modified-id="Solution-1:-Use-Decimal-Degrees-Precision-of-Coordinates-4.1.3.1"><span class="toc-item-num">4.1.3.1&nbsp;&nbsp;</span>Solution 1: Use Decimal Degrees Precision of Coordinates</a></span></li><li><span><a href="#Solution-2:-Use-Haversine-method-(with-numpy)" data-toc-modified-id="Solution-2:-Use-Haversine-method-(with-numpy)-4.1.3.2"><span class="toc-item-num">4.1.3.2&nbsp;&nbsp;</span>Solution 2: Use Haversine method (with numpy)</a></span></li><li><span><a href="#Finally,-dropping-the-vicinity-cases" data-toc-modified-id="Finally,-dropping-the-vicinity-cases-4.1.3.3"><span class="toc-item-num">4.1.3.3&nbsp;&nbsp;</span>Finally, dropping the vicinity cases</a></span></li></ul></li><li><span><a href="#Only-focus-on-trucks-that-were-involved-in-spn-==-1569-or-spn-==-5246" data-toc-modified-id="Only-focus-on-trucks-that-were-involved-in-spn-==-1569-or-spn-==-5246-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Only focus on trucks that were involved in <code>spn == 1569</code> or <code>spn == 5246</code></a></span></li></ul></li></ul></li><li><span><a href="#Sample-Truck-With-Multiple-Records:-1490" data-toc-modified-id="Sample-Truck-With-Multiple-Records:-1490-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Sample Truck With Multiple Records: <code>1490</code></a></span></li><li><span><a href="#Looking-At-service_fault_codes" data-toc-modified-id="Looking-At-service_fault_codes-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Looking At <code>service_fault_codes</code></a></span><ul class="toc-item"><li><span><a href="#Data-Cleanups-service_fault_codes" data-toc-modified-id="Data-Cleanups-service_fault_codes-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Data Cleanups <code>service_fault_codes</code></a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Libraries and Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
engine_faults = pd.read_csv(
    "../data/J1939Faults.csv", 
    low_memory=False
)

# %%
diagnostics = pd.read_csv(
    "../data/VehicleDiagnosticOnboardData.csv", 
    low_memory=False
)

# %%
service_fault_codes = pd.read_excel(
    "../data/Service Fault Codes_1_0_0_167.xlsx", 
    sheet_name="Published 14602 App A core II",
    engine="openpyxl"
)
# Out:
# C:\Users\maeva\anaconda3\envs\default\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
# This is old data: We can't use it
# vehicle_makes = pd.read_excel(
#     '../data/Vehicle_Make.xlsx', 
#     sheet_name='Sheet1',
#     engine="openpyxl"
# )

# %% [markdown]
# ## Looking at `engine_faults`

# %%
display(engine_faults.shape)
display(engine_faults.head())
display(engine_faults.tail())
display(engine_faults.info())
# Out:
# (1187335, 20)
#    RecordID  ESS_Id           EventTimeStamp  \
# 0         1  990349  2015-02-21 10:47:13.000
# 1         2  990360  2015-02-21 11:34:34.000
# 2         3  990364  2015-02-21 11:35:31.000
# 3         4  990370  2015-02-21 11:35:33.000
# 4         5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription  actionDescription  \
# 0  Low (Severity Low) Engine Coolant Level                NaN
# 1                                      NaN                NaN
# 2      Incorrect Data Steering Wheel Angle                NaN
# 3      Incorrect Data Steering Wheel Angle                NaN
# 4                                      NaN                NaN
#
#                      ecuSoftwareVersion ecuSerialNumber              ecuModel  \
# 0                               unknown         unknown               unknown
# 1                               unknown         unknown               unknown
# 2                               unknown         unknown               unknown
# 3                               unknown         unknown               unknown
# 4  22281684P01*22357957P01*22362082P01*        13063430  0USA13_13_0415_2238A
#
#    ecuMake  ecuSource   spn  fmi  active  activeTransitionCount  faultValue  \
# 0  unknown          0   111   17    True                      2         NaN
# 1  unknown         11   629   12    True                    127         NaN
# 2  unknown         11  1807    2   False                    127         NaN
# 3  unknown         11  1807    2    True                    127         NaN
# 4    VOLVO          0  4364   17   False                      2         NaN
#
#   EquipmentID  MCTNumber   Latitude  Longitude        LocationTimeStamp
# 0        1439  105354361  38.857638 -84.626851  2015-02-21 11:34:25.000
# 1        1439  105354361  38.857638 -84.626851  2015-02-21 11:35:10.000
# 2        1369  105336226  41.421250 -87.767361  2015-02-21 11:35:26.000
# 3        1369  105336226  41.421018 -87.767361  2015-02-21 11:36:08.000
# 4        1674  105427130  38.416481 -89.442638  2015-02-21 11:39:37.000
#          RecordID     ESS_Id           EventTimeStamp  \
# 1187330   1248454  123904424  2020-03-06 14:00:26.000
# 1187331   1248455  123905139  2020-03-06 14:04:23.000
# 1187332   1248456  123905996  2020-03-06 14:13:38.000
# 1187333   1248457  123906113  2020-03-06 14:14:13.000
# 1187334   1248458  123906131  2020-03-06 14:15:34.000
#
#                                           eventDescription  actionDescription  \
# 1187330             Low (Severity Low) Catalyst Tank Level                NaN
# 1187331   Condition Exists Engine Protection Torque Derate                NaN
# 1187332  Abnormal Rate of Change Aftertreatment 1 Intak...                NaN
# 1187333         Low (Severity Medium) Engine Coolant Level                NaN
# 1187334         Low (Severity Medium) Engine Coolant Level                NaN
#
#                                       ecuSoftwareVersion ecuSerialNumber  \
# 1187330  04384413*22383729*082218154102*60701732*G1*BGT*        80156139
# 1187331  04358814*06099720*030816202706*09400153*G1*BDR*        79932020
# 1187332  05317106*05100987*050719120655*09401585*G1*BDR*        79880653
# 1187333  04384413*22544852*090619141107*60701756*G1*BGT*             NaN
# 1187334  04384413*22544852*090619141107*60701756*G1*BGT*             NaN
#
#                   ecuModel ecuMake  ecuSource   spn  fmi  active  \
# 1187330  6X1u17D1500000000   CMMNS          0  1761   17   False
# 1187331  6X1u13D1500000000   CMMNS          0  1569   31    True
# 1187332  6X1u13D1500000000   CMMNS          0  3216   10    True
# 1187333                NaN     NaN          0   111   18    True
# 1187334                NaN     NaN          0   111   18   False
#
#          activeTransitionCount  faultValue EquipmentID  MCTNumber   Latitude  \
# 1187330                      3         NaN        2282  105439740  37.094768
# 1187331                      5         NaN        1994  105354084  34.390740
# 1187332                      1         NaN        1850  105336308  34.430370
# 1187333                      8         NaN        2377  108605700  35.030925
# 1187334                      8         NaN        2377  108605700  35.027314
#
#          Longitude        LocationTimeStamp
# 1187330 -85.897407  2020-03-06 14:00:21.000
# 1187331 -79.461805  2020-03-06 14:04:59.000
# 1187332 -84.920509  2020-03-06 14:14:14.000
# 1187333 -85.321527  2020-03-06 14:14:49.000
# 1187334 -85.323472  2020-03-06 14:15:30.000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187335 entries, 0 to 1187334
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   RecordID               1187335 non-null  int64
#  1   ESS_Id                 1187335 non-null  int64
#  2   EventTimeStamp         1187335 non-null  object
#  3   eventDescription       1126490 non-null  object
#  4   actionDescription      0 non-null        float64
#  5   ecuSoftwareVersion     891285 non-null   object
#  6   ecuSerialNumber        844318 non-null   object
#  7   ecuModel               1122577 non-null  object
#  8   ecuMake                1122577 non-null  object
#  9   ecuSource              1187335 non-null  int64
#  10  spn                    1187335 non-null  int64
#  11  fmi                    1187335 non-null  int64
#  12  active                 1187335 non-null  bool
#  13  activeTransitionCount  1187335 non-null  int64
#  14  faultValue             0 non-null        float64
#  15  EquipmentID            1187335 non-null  object
#  16  MCTNumber              1187335 non-null  int64
#  17  Latitude               1187335 non-null  float64
#  18  Longitude              1187335 non-null  float64
#  19  LocationTimeStamp      1187335 non-null  object
# dtypes: bool(1), float64(4), int64(7), object(8)
# memory usage: 173.2+ MB
# None

# %% [markdown]
# ### Provided Data Dictionary for `engine_faults`
#
# Columns | Description
# :-------|:-----------
# `ESS_Id` | The event subscriber service event that contained the fault
# `EventTimeStamp` | When the event took place
# `eventDescription` | Brief text of meaning of the code (not always present)
# `actionDescription` | Never seen this filled in
# `ecuSoftwareVersion` | version string from the reporting vehicle computer system
# `ecuSerialNumber` | Serial number of the reporting Engine Control Module (ECM)
# `ecuModel` | Model of the reporting ECM
# `ecuMake` | Manufacturer of the reporting ECM
# `ecuSource` |
# `spn` | Fault code being reported
# `fmi` | Failure Mode associated with the Fault Code
# `active` | Whether the code is being set or being removed
# `activeTransitionCount` | Number of times code has been set/unset
# `faultValue` | Never seen used
# `EquipmentID` | Assigned truck number of the unit in question
# `MCTNumber` | Communications Terminal assigned to the truck
# `Latitude` | Latitude at time of event
# `Longitude` | Longitude at time of event
# `LocationTimeStamp` | Time latitude and longitude were obtained

# %% [markdown]
# ### Data Cleanups `engine_Faults`

# %%
# Drop these columns: There are no data in these columns (Just `NaN`)
engine_faults = engine_faults.drop(columns=["actionDescription", "faultValue"])

# %%
# Rename all columns to format "column_name"
engine_faults = engine_faults.rename(columns={
    "RecordID": "record_id",
    "ESS_Id": "ess_id",
    "EventTimeStamp": "event_timestamp",
    "eventDescription": "event_description",
    "actionDescription": "action_description",
    "ecuSoftwareVersion": "ecu_software_version",
    "ecuSerialNumber": "ecu_serial_number",
    "ecuModel": "ecu_model",
    "ecuMake": "ecu_make",
    "ecuSource": "ecu_source",
    "activeTransitionCount": "active_transition_count",
    "faultValue": "fault_value",
    "EquipmentID": "equipment_id",
    "MCTNumber": "mct_number",
    "Latitude": "latitude",
    "Longitude": "longitude",
    "LocationTimeStamp": "location_timestamp"
})

# %%
# Columns To String
to_string_columns = [
    "record_id", 
    "ess_id",
    "event_description",
    "ecu_software_version",
    "ecu_serial_number",
    "ecu_model",
    "ecu_make",
    "ecu_source",
    "spn",
    "fmi",
    "equipment_id",
    "mct_number",
    #"latitude",
    #"longitude"
]

for col in to_string_columns:
    engine_faults[col] = engine_faults[col].astype("str")

# %%
# Columns To Boolean
engine_faults["active"] = engine_faults["active"].astype("bool")

# %%
# Columns To Integer
engine_faults["active_transition_count"] = engine_faults["active_transition_count"].astype("int64")

# %%
# Columns To Float
engine_faults["latitude"] = engine_faults["latitude"].astype("float64")
engine_faults["longitude"] = engine_faults["longitude"].astype("float64")

# %%
# Columns To datetime
engine_faults["event_timestamp"] = engine_faults["event_timestamp"].astype("datetime64")
engine_faults["location_timestamp"] = engine_faults["location_timestamp"].astype("datetime64")

# %%
# Check where we are
display(engine_faults.shape)
# Out:
# (1187335, 18)

# %% [markdown]
# ### Final `engine_faults` before merge

# %%
display(engine_faults.shape)
display(engine_faults.head())
display(engine_faults.tail())
display(engine_faults.info())
# Out:
# (1187335, 18)
#   record_id  ess_id     event_timestamp  \
# 0         1  990349 2015-02-21 10:47:13
# 1         2  990360 2015-02-21 11:34:34
# 2         3  990364 2015-02-21 11:35:31
# 3         4  990370 2015-02-21 11:35:33
# 4         5  990416 2015-02-21 11:39:41
#
#                          event_description  \
# 0  Low (Severity Low) Engine Coolant Level
# 1                                      nan
# 2      Incorrect Data Steering Wheel Angle
# 3      Incorrect Data Steering Wheel Angle
# 4                                      nan
#
#                    ecu_software_version ecu_serial_number  \
# 0                               unknown           unknown
# 1                               unknown           unknown
# 2                               unknown           unknown
# 3                               unknown           unknown
# 4  22281684P01*22357957P01*22362082P01*          13063430
#
#               ecu_model ecu_make ecu_source   spn fmi  active  \
# 0               unknown  unknown          0   111  17    True
# 1               unknown  unknown         11   629  12    True
# 2               unknown  unknown         11  1807   2   False
# 3               unknown  unknown         11  1807   2    True
# 4  0USA13_13_0415_2238A    VOLVO          0  4364  17   False
#
#    active_transition_count equipment_id mct_number   latitude  longitude  \
# 0                        2         1439  105354361  38.857638 -84.626851
# 1                      127         1439  105354361  38.857638 -84.626851
# 2                      127         1369  105336226  41.421250 -87.767361
# 3                      127         1369  105336226  41.421018 -87.767361
# 4                        2         1674  105427130  38.416481 -89.442638
#
#    location_timestamp
# 0 2015-02-21 11:34:25
# 1 2015-02-21 11:35:10
# 2 2015-02-21 11:35:26
# 3 2015-02-21 11:36:08
# 4 2015-02-21 11:39:37
#         record_id     ess_id     event_timestamp  \
# 1187330   1248454  123904424 2020-03-06 14:00:26
# 1187331   1248455  123905139 2020-03-06 14:04:23
# 1187332   1248456  123905996 2020-03-06 14:13:38
# 1187333   1248457  123906113 2020-03-06 14:14:13
# 1187334   1248458  123906131 2020-03-06 14:15:34
#
#                                          event_description  \
# 1187330             Low (Severity Low) Catalyst Tank Level
# 1187331   Condition Exists Engine Protection Torque Derate
# 1187332  Abnormal Rate of Change Aftertreatment 1 Intak...
# 1187333         Low (Severity Medium) Engine Coolant Level
# 1187334         Low (Severity Medium) Engine Coolant Level
#
#                                     ecu_software_version ecu_serial_number  \
# 1187330  04384413*22383729*082218154102*60701732*G1*BGT*          80156139
# 1187331  04358814*06099720*030816202706*09400153*G1*BDR*          79932020
# 1187332  05317106*05100987*050719120655*09401585*G1*BDR*          79880653
# 1187333  04384413*22544852*090619141107*60701756*G1*BGT*               nan
# 1187334  04384413*22544852*090619141107*60701756*G1*BGT*               nan
#
#                  ecu_model ecu_make ecu_source   spn fmi  active  \
# 1187330  6X1u17D1500000000    CMMNS          0  1761  17   False
# 1187331  6X1u13D1500000000    CMMNS          0  1569  31    True
# 1187332  6X1u13D1500000000    CMMNS          0  3216  10    True
# 1187333                nan      nan          0   111  18    True
# 1187334                nan      nan          0   111  18   False
#
#          active_transition_count equipment_id mct_number   latitude  \
# 1187330                        3         2282  105439740  37.094768
# 1187331                        5         1994  105354084  34.390740
# 1187332                        1         1850  105336308  34.430370
# 1187333                        8         2377  108605700  35.030925
# 1187334                        8         2377  108605700  35.027314
#
#          longitude  location_timestamp
# 1187330 -85.897407 2020-03-06 14:00:21
# 1187331 -79.461805 2020-03-06 14:04:59
# 1187332 -84.920509 2020-03-06 14:14:14
# 1187333 -85.321527 2020-03-06 14:14:49
# 1187334 -85.323472 2020-03-06 14:15:30
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187335 entries, 0 to 1187334
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   record_id                1187335 non-null  object
#  1   ess_id                   1187335 non-null  object
#  2   event_timestamp          1187335 non-null  datetime64[ns]
#  3   event_description        1187335 non-null  object
#  4   ecu_software_version     1187335 non-null  object
#  5   ecu_serial_number        1187335 non-null  object
#  6   ecu_model                1187335 non-null  object
#  7   ecu_make                 1187335 non-null  object
#  8   ecu_source               1187335 non-null  object
#  9   spn                      1187335 non-null  object
#  10  fmi                      1187335 non-null  object
#  11  active                   1187335 non-null  bool
#  12  active_transition_count  1187335 non-null  int64
#  13  equipment_id             1187335 non-null  object
#  14  mct_number               1187335 non-null  object
#  15  latitude                 1187335 non-null  float64
#  16  longitude                1187335 non-null  float64
#  17  location_timestamp       1187335 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](2), float64(2), int64(1), object(12)
# memory usage: 155.1+ MB
# None

# %% [markdown]
# ## Looking at `diagnostics`

# %%
display(diagnostics.shape)
display(diagnostics.head(5))
display(diagnostics.tail(5))
display(diagnostics.info())
# Out:
# (12821626, 4)
#    Id                  Name     Value  FaultId
# 0   1             IgnStatus     False        1
# 1   2     EngineOilPressure         0        1
# 2   3  EngineOilTemperature  96.74375        1
# 3   4    TurboBoostPressure         0        1
# 4   5            EngineLoad        11        1
#                 Id                      Name        Value  FaultId
# 12821621  12864020  EngineCoolantTemperature        181.4  1248457
# 12821622  12864021              ParkingBrake        False  1248457
# 12821623  12864022    SwitchedBatteryVoltage         14.1  1248457
# 12821624  12864023               DistanceLtd  28606.65625  1248457
# 12821625  12864024                LampStatus         1023  1248458
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12821626 entries, 0 to 12821625
# Data columns (total 4 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   Id       int64
#  1   Name     object
#  2   Value    object
#  3   FaultId  int64
# dtypes: int64(2), object(2)
# memory usage: 391.3+ MB
# None

# %% [markdown]
# ### Data Cleanups: `diagnostics`

# %%
# Pivotting
diagnostics = diagnostics.pivot(index = 'FaultId', columns='Name', values='Value').reset_index()

# %%
# Rename all columns to format "column_name"
diagnostics = diagnostics.rename(columns={
    "FaultId": "fault_id",
    "AcceleratorPedal": "accelerator_pedal",
    "BarometricPressure": "barometric_pressure",
    "CruiseControlActive": "cruise_control_active",
    "CruiseControlSetSpeed": "cruise_control_set_speed",
    "DistanceLtd": "distance_ltd",
    "EngineCoolantTemperature": "engine_coolant_temperature",
    "EngineLoad": "engine_load",
    "EngineOilPressure": "engine_oil_pressure",
    "EngineOilTemperature": "engine_oil_temperature",
    "EngineRpm": "engine_rpm",
    "EngineTimeLtd": "engine_time_ltd",
    "FuelLevel": "fuel_level",
    "FuelLtd": "fuel_ltd",
    "FuelRate": "fuel_rate",
    "FuelTemperature": "fuel_temperature",
    "IgnStatus": "ign_status",
    "IntakeManifoldTemperature": "intake_manifold_temperature",
    "LampStatus": "lamp_status",
    "ParkingBrake": "parking_brake",
    "ServiceDistance": "service_distance",
    "Speed": "speed",
    "SwitchedBatteryVoltage": "switched_battery_voltage",
    "Throttle": "throttle",
    "TurboBoostPressure": "turbo_boost_pressure"
})

# %%
# Columns To String
diagnostics["fault_id"] = diagnostics["fault_id"].astype("str")
diagnostics["lamp_status"] = diagnostics["lamp_status"].astype("str")

# %%
# Columns To Boolean
diagnostics["cruise_control_active"] = diagnostics["cruise_control_active"].astype("bool")
diagnostics["ign_status"] = diagnostics["ign_status"].astype("bool")
diagnostics["parking_brake"] = diagnostics["parking_brake"].astype("bool")

# %%
# Columns To Float
to_float_columns = [
    "accelerator_pedal", 
    "barometric_pressure",
    "cruise_control_set_speed",
    "distance_ltd",
    "engine_coolant_temperature",
    "engine_load",
    "engine_oil_pressure",
    "engine_oil_temperature",
    "engine_rpm",
    "engine_time_ltd",
    "fuel_level",
    "fuel_ltd",
    "fuel_rate",
    "fuel_temperature",
    "intake_manifold_temperature",
    "service_distance",
    "speed",
    "switched_battery_voltage",
    "throttle",
    "turbo_boost_pressure"
]

for col in to_float_columns:
    diagnostics[col] = diagnostics[col].str.replace(',', '.')
    diagnostics[col] = diagnostics[col].astype("float64")

# %%
# Change column name fault_id to record_id for consistency
diagnostics = diagnostics.rename(columns={"fault_id":"record_id"})

# %% [markdown]
# ### Final `diagnostics` before merge

# %%
# Check where we are
display(diagnostics.shape)
display(diagnostics.head())
display(diagnostics.tail())
display(diagnostics.info())
# Out:
# (1187335, 25)
# Name record_id  accelerator_pedal  barometric_pressure  cruise_control_active  \
# 0            1                0.0                14.21                   True
# 1            2                NaN                  NaN                   True
# 2            3                NaN                  NaN                   True
# 3            4                NaN                  NaN                   True
# 4            5                NaN                  NaN                   True
#
# Name  cruise_control_set_speed  distance_ltd  engine_coolant_temperature  \
# 0                     66.48672      423178.7                       100.4
# 1                          NaN           NaN                         NaN
# 2                          NaN           NaN                         NaN
# 3                          NaN           NaN                         NaN
# 4                          NaN           NaN                         NaN
#
# Name  engine_load  engine_oil_pressure  engine_oil_temperature  engine_rpm  \
# 0            11.0                  0.0                96.74375         0.0
# 1             NaN                  NaN                     NaN         NaN
# 2             NaN                  NaN                     NaN         NaN
# 3             NaN                  NaN                     NaN         NaN
# 4             NaN                  NaN                     NaN         NaN
#
# Name  engine_time_ltd  fuel_level      fuel_ltd  fuel_rate  fuel_temperature  \
# 0              1632.2        43.2  12300.907429        0.0               NaN
# 1                 NaN         NaN           NaN        NaN               NaN
# 2                 NaN         NaN           NaN        NaN               NaN
# 3                 NaN         NaN           NaN        NaN               NaN
# 4                 NaN         NaN           NaN        NaN               NaN
#
# Name  ign_status  intake_manifold_temperature lamp_status  parking_brake  \
# 0           True                         78.8        1023           True
# 1           True                          NaN        1279           True
# 2           True                          NaN        1279           True
# 3           True                          NaN        1279           True
# 4           True                          NaN       16639           True
#
# Name  service_distance  speed  switched_battery_voltage  throttle  \
# 0                  NaN    0.0                   3276.75       NaN
# 1                  NaN    NaN                       NaN       NaN
# 2                  NaN    NaN                       NaN       NaN
# 3                  NaN    NaN                       NaN       NaN
# 4                  NaN    NaN                       NaN       NaN
#
# Name  turbo_boost_pressure
# 0                      0.0
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# Name    record_id  accelerator_pedal  barometric_pressure  \
# 1187330   1248454                NaN                  NaN
# 1187331   1248455              100.0              14.5000
# 1187332   1248456                0.0              14.3550
# 1187333   1248457                1.6              14.4275
# 1187334   1248458                NaN                  NaN
#
# Name     cruise_control_active  cruise_control_set_speed  distance_ltd  \
# 1187330                   True                       NaN           NaN
# 1187331                   True                  64.62260  423937.90000
# 1187332                   True                  66.48672  465925.40000
# 1187333                   True                  67.72946   28606.65625
# 1187334                   True                       NaN           NaN
#
# Name     engine_coolant_temperature  engine_load  engine_oil_pressure  \
# 1187330                         NaN          NaN                  NaN
# 1187331                       185.0         51.0                37.12
# 1187332                       186.8         62.0                41.18
# 1187333                       181.4          0.0                27.26
# 1187334                         NaN          NaN                  NaN
#
# Name     engine_oil_temperature  engine_rpm  engine_time_ltd  fuel_level  \
# 1187330                     NaN         NaN              NaN         NaN
# 1187331                211.4937     1310.25         10722.70        96.4
# 1187332                212.8438     1340.75          9326.75       100.0
# 1187333                221.7312      863.25           586.75        23.6
# 1187334                     NaN         NaN              NaN         NaN
#
# Name         fuel_ltd  fuel_rate  fuel_temperature  ign_status  \
# 1187330           NaN        NaN               NaN        True
# 1187331  58979.184416   7.647805              32.0        True
# 1187332  65080.105870   8.995086               NaN        True
# 1187333   4042.492826   0.000000               NaN        True
# 1187334           NaN        NaN               NaN        True
#
# Name     intake_manifold_temperature lamp_status  parking_brake  \
# 1187330                          NaN        1023           True
# 1187331                         98.6       18431           True
# 1187332                         91.4       17407           True
# 1187333                        100.4        1023           True
# 1187334                          NaN        1023           True
#
# Name     service_distance     speed  switched_battery_voltage  throttle  \
# 1187330               NaN       NaN                       NaN       NaN
# 1187331               NaN  65.01096                       NaN      73.2
# 1187332               NaN  66.57410                       NaN     100.0
# 1187333               NaN  11.84489                      14.1     100.0
# 1187334               NaN       NaN                       NaN       NaN
#
# Name     turbo_boost_pressure
# 1187330                   NaN
# 1187331                  7.83
# 1187332                  6.96
# 1187333                  1.74
# 1187334                   NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187335 entries, 0 to 1187334
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   record_id                    1187335 non-null  object
#  1   accelerator_pedal            531889 non-null   float64
#  2   barometric_pressure          585976 non-null   float64
#  3   cruise_control_active        1187335 non-null  bool
#  4   cruise_control_set_speed     576458 non-null   float64
#  5   distance_ltd                 585819 non-null   float64
#  6   engine_coolant_temperature   586071 non-null   float64
#  7   engine_load                  585621 non-null   float64
#  8   engine_oil_pressure          586244 non-null   float64
#  9   engine_oil_temperature       583912 non-null   float64
#  10  engine_rpm                   586921 non-null   float64
#  11  engine_time_ltd              581366 non-null   float64
#  12  fuel_level                   502795 non-null   float64
#  13  fuel_ltd                     585195 non-null   float64
#  14  fuel_rate                    585237 non-null   float64
#  15  fuel_temperature             299110 non-null   float64
#  16  ign_status                   1187335 non-null  bool
#  17  intake_manifold_temperature  586291 non-null   float64
#  18  lamp_status                  1187335 non-null  object
#  19  parking_brake                1187335 non-null  bool
#  20  service_distance             215 non-null      float64
#  21  speed                        583916 non-null   float64
#  22  switched_battery_voltage     114059 non-null   float64
#  23  throttle                     420503 non-null   float64
#  24  turbo_boost_pressure         583351 non-null   float64
# dtypes: bool(3), float64(20), object(2)
# memory usage: 202.7+ MB
# None

# %% [markdown]
# ## Merging `engine_faults` and `diagnostics`

# %%
engine_faults_diag = engine_faults.merge(
    diagnostics, 
    on = "record_id", 
    how="right",
    suffixes = ('_faults', '_diag')
)

# %%
# Check where we are
display(engine_faults_diag.shape)
display(engine_faults_diag.head())
display(engine_faults_diag.tail())
display(engine_faults_diag.info())
# Out:
# (1187335, 42)
#   record_id  ess_id     event_timestamp  \
# 0         1  990349 2015-02-21 10:47:13
# 1         2  990360 2015-02-21 11:34:34
# 2         3  990364 2015-02-21 11:35:31
# 3         4  990370 2015-02-21 11:35:33
# 4         5  990416 2015-02-21 11:39:41
#
#                          event_description  \
# 0  Low (Severity Low) Engine Coolant Level
# 1                                      nan
# 2      Incorrect Data Steering Wheel Angle
# 3      Incorrect Data Steering Wheel Angle
# 4                                      nan
#
#                    ecu_software_version ecu_serial_number  \
# 0                               unknown           unknown
# 1                               unknown           unknown
# 2                               unknown           unknown
# 3                               unknown           unknown
# 4  22281684P01*22357957P01*22362082P01*          13063430
#
#               ecu_model ecu_make ecu_source   spn fmi  active  \
# 0               unknown  unknown          0   111  17    True
# 1               unknown  unknown         11   629  12    True
# 2               unknown  unknown         11  1807   2   False
# 3               unknown  unknown         11  1807   2    True
# 4  0USA13_13_0415_2238A    VOLVO          0  4364  17   False
#
#    active_transition_count equipment_id mct_number   latitude  longitude  \
# 0                        2         1439  105354361  38.857638 -84.626851
# 1                      127         1439  105354361  38.857638 -84.626851
# 2                      127         1369  105336226  41.421250 -87.767361
# 3                      127         1369  105336226  41.421018 -87.767361
# 4                        2         1674  105427130  38.416481 -89.442638
#
#    location_timestamp  accelerator_pedal  barometric_pressure  \
# 0 2015-02-21 11:34:25                0.0                14.21
# 1 2015-02-21 11:35:10                NaN                  NaN
# 2 2015-02-21 11:35:26                NaN                  NaN
# 3 2015-02-21 11:36:08                NaN                  NaN
# 4 2015-02-21 11:39:37                NaN                  NaN
#
#    cruise_control_active  cruise_control_set_speed  distance_ltd  \
# 0                   True                  66.48672      423178.7
# 1                   True                       NaN           NaN
# 2                   True                       NaN           NaN
# 3                   True                       NaN           NaN
# 4                   True                       NaN           NaN
#
#    engine_coolant_temperature  engine_load  engine_oil_pressure  \
# 0                       100.4         11.0                  0.0
# 1                         NaN          NaN                  NaN
# 2                         NaN          NaN                  NaN
# 3                         NaN          NaN                  NaN
# 4                         NaN          NaN                  NaN
#
#    engine_oil_temperature  engine_rpm  engine_time_ltd  fuel_level  \
# 0                96.74375         0.0           1632.2        43.2
# 1                     NaN         NaN              NaN         NaN
# 2                     NaN         NaN              NaN         NaN
# 3                     NaN         NaN              NaN         NaN
# 4                     NaN         NaN              NaN         NaN
#
#        fuel_ltd  fuel_rate  fuel_temperature  ign_status  \
# 0  12300.907429        0.0               NaN        True
# 1           NaN        NaN               NaN        True
# 2           NaN        NaN               NaN        True
# 3           NaN        NaN               NaN        True
# 4           NaN        NaN               NaN        True
#
#    intake_manifold_temperature lamp_status  parking_brake  service_distance  \
# 0                         78.8        1023           True               NaN
# 1                          NaN        1279           True               NaN
# 2                          NaN        1279           True               NaN
# 3                          NaN        1279           True               NaN
# 4                          NaN       16639           True               NaN
#
#    speed  switched_battery_voltage  throttle  turbo_boost_pressure
# 0    0.0                   3276.75       NaN                   0.0
# 1    NaN                       NaN       NaN                   NaN
# 2    NaN                       NaN       NaN                   NaN
# 3    NaN                       NaN       NaN                   NaN
# 4    NaN                       NaN       NaN                   NaN
#         record_id     ess_id     event_timestamp  \
# 1187330   1248454  123904424 2020-03-06 14:00:26
# 1187331   1248455  123905139 2020-03-06 14:04:23
# 1187332   1248456  123905996 2020-03-06 14:13:38
# 1187333   1248457  123906113 2020-03-06 14:14:13
# 1187334   1248458  123906131 2020-03-06 14:15:34
#
#                                          event_description  \
# 1187330             Low (Severity Low) Catalyst Tank Level
# 1187331   Condition Exists Engine Protection Torque Derate
# 1187332  Abnormal Rate of Change Aftertreatment 1 Intak...
# 1187333         Low (Severity Medium) Engine Coolant Level
# 1187334         Low (Severity Medium) Engine Coolant Level
#
#                                     ecu_software_version ecu_serial_number  \
# 1187330  04384413*22383729*082218154102*60701732*G1*BGT*          80156139
# 1187331  04358814*06099720*030816202706*09400153*G1*BDR*          79932020
# 1187332  05317106*05100987*050719120655*09401585*G1*BDR*          79880653
# 1187333  04384413*22544852*090619141107*60701756*G1*BGT*               nan
# 1187334  04384413*22544852*090619141107*60701756*G1*BGT*               nan
#
#                  ecu_model ecu_make ecu_source   spn fmi  active  \
# 1187330  6X1u17D1500000000    CMMNS          0  1761  17   False
# 1187331  6X1u13D1500000000    CMMNS          0  1569  31    True
# 1187332  6X1u13D1500000000    CMMNS          0  3216  10    True
# 1187333                nan      nan          0   111  18    True
# 1187334                nan      nan          0   111  18   False
#
#          active_transition_count equipment_id mct_number   latitude  \
# 1187330                        3         2282  105439740  37.094768
# 1187331                        5         1994  105354084  34.390740
# 1187332                        1         1850  105336308  34.430370
# 1187333                        8         2377  108605700  35.030925
# 1187334                        8         2377  108605700  35.027314
#
#          longitude  location_timestamp  accelerator_pedal  \
# 1187330 -85.897407 2020-03-06 14:00:21                NaN
# 1187331 -79.461805 2020-03-06 14:04:59              100.0
# 1187332 -84.920509 2020-03-06 14:14:14                0.0
# 1187333 -85.321527 2020-03-06 14:14:49                1.6
# 1187334 -85.323472 2020-03-06 14:15:30                NaN
#
#          barometric_pressure  cruise_control_active  cruise_control_set_speed  \
# 1187330                  NaN                   True                       NaN
# 1187331              14.5000                   True                  64.62260
# 1187332              14.3550                   True                  66.48672
# 1187333              14.4275                   True                  67.72946
# 1187334                  NaN                   True                       NaN
#
#          distance_ltd  engine_coolant_temperature  engine_load  \
# 1187330           NaN                         NaN          NaN
# 1187331  423937.90000                       185.0         51.0
# 1187332  465925.40000                       186.8         62.0
# 1187333   28606.65625                       181.4          0.0
# 1187334           NaN                         NaN          NaN
#
#          engine_oil_pressure  engine_oil_temperature  engine_rpm  \
# 1187330                  NaN                     NaN         NaN
# 1187331                37.12                211.4937     1310.25
# 1187332                41.18                212.8438     1340.75
# 1187333                27.26                221.7312      863.25
# 1187334                  NaN                     NaN         NaN
#
#          engine_time_ltd  fuel_level      fuel_ltd  fuel_rate  \
# 1187330              NaN         NaN           NaN        NaN
# 1187331         10722.70        96.4  58979.184416   7.647805
# 1187332          9326.75       100.0  65080.105870   8.995086
# 1187333           586.75        23.6   4042.492826   0.000000
# 1187334              NaN         NaN           NaN        NaN
#
#          fuel_temperature  ign_status  intake_manifold_temperature  \
# 1187330               NaN        True                          NaN
# 1187331              32.0        True                         98.6
# 1187332               NaN        True                         91.4
# 1187333               NaN        True                        100.4
# 1187334               NaN        True                          NaN
#
#         lamp_status  parking_brake  service_distance     speed  \
# 1187330        1023           True               NaN       NaN
# 1187331       18431           True               NaN  65.01096
# 1187332       17407           True               NaN  66.57410
# 1187333        1023           True               NaN  11.84489
# 1187334        1023           True               NaN       NaN
#
#          switched_battery_voltage  throttle  turbo_boost_pressure
# 1187330                       NaN       NaN                   NaN
# 1187331                       NaN      73.2                  7.83
# 1187332                       NaN     100.0                  6.96
# 1187333                      14.1     100.0                  1.74
# 1187334                       NaN       NaN                   NaN
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1187335 entries, 0 to 1187334
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   record_id                    1187335 non-null  object
#  1   ess_id                       1187335 non-null  object
#  2   event_timestamp              1187335 non-null  datetime64[ns]
#  3   event_description            1187335 non-null  object
#  4   ecu_software_version         1187335 non-null  object
#  5   ecu_serial_number            1187335 non-null  object
#  6   ecu_model                    1187335 non-null  object
#  7   ecu_make                     1187335 non-null  object
#  8   ecu_source                   1187335 non-null  object
#  9   spn                          1187335 non-null  object
#  10  fmi                          1187335 non-null  object
#  11  active                       1187335 non-null  bool
#  12  active_transition_count      1187335 non-null  int64
#  13  equipment_id                 1187335 non-null  object
#  14  mct_number                   1187335 non-null  object
#  15  latitude                     1187335 non-null  float64
#  16  longitude                    1187335 non-null  float64
#  17  location_timestamp           1187335 non-null  datetime64[ns]
#  18  accelerator_pedal            531889 non-null   float64
#  19  barometric_pressure          585976 non-null   float64
#  20  cruise_control_active        1187335 non-null  bool
#  21  cruise_control_set_speed     576458 non-null   float64
#  22  distance_ltd                 585819 non-null   float64
#  23  engine_coolant_temperature   586071 non-null   float64
#  24  engine_load                  585621 non-null   float64
#  25  engine_oil_pressure          586244 non-null   float64
#  26  engine_oil_temperature       583912 non-null   float64
#  27  engine_rpm                   586921 non-null   float64
#  28  engine_time_ltd              581366 non-null   float64
#  29  fuel_level                   502795 non-null   float64
#  30  fuel_ltd                     585195 non-null   float64
#  31  fuel_rate                    585237 non-null   float64
#  32  fuel_temperature             299110 non-null   float64
#  33  ign_status                   1187335 non-null  bool
#  34  intake_manifold_temperature  586291 non-null   float64
#  35  lamp_status                  1187335 non-null  object
#  36  parking_brake                1187335 non-null  bool
#  37  service_distance             215 non-null      float64
#  38  speed                        583916 non-null   float64
#  39  switched_battery_voltage     114059 non-null   float64
#  40  throttle                     420503 non-null   float64
#  41  turbo_boost_pressure         583351 non-null   float64
# dtypes: bool(4), datetime64[ns](2), float64(22), int64(1), object(13)
# memory usage: 357.8+ MB
# None

# %% [markdown]
# ### Additional Data Cleanups Post-Merging

# %% [markdown]
# #### Remove faults where equipmentID has more than 5 characters

# %%
engine_faults_diag = engine_faults_diag[engine_faults_diag["equipment_id"].map(len) <= 5]

# %%
# Check where we are
display(engine_faults_diag.shape)
# Out:
# (1185166, 42)

# %% [markdown]
# #### Remove faults where `active` is set to `False`

# %%
engine_faults_diag = engine_faults_diag[engine_faults_diag["active"] != False]

# %%
# Check where we are
display(engine_faults_diag.shape)
# Out:
# (607336, 42)

# %% [markdown]
# #### Remove faults in the vicinity of service location

# %% [markdown]
# The service locations:
#
# - `(36.0666667, -86.4347222)`
# - `(35.5883333, -86.4438888)`
# - `(36.1950, -83.174722)`

# %% [markdown]
# **Coordinates Precision**
#
# Decimal Places | Decimal Degrees | Object that can be unambiguously recognized at this scale
# :-------------:|-----------------|:---------------------------------------------------------
# 0 | 1.0 | country or large region
# 1 | 0.1 | large city or district
# 2 | 0.01 | town or village
# 3 | 0.001 | neighborhood, street
# 4 | 0.0001 | individual street, large buildings
# 5 | 0.00001 | individual trees, houses
# 6 | 0.000001 | individual humans
# 7 | 0.0000001 | practical limit of commercial surveying
# 8 | 0.00000001 | specialized surveying (e.g. tectonic plate mapping)

# %% [markdown]
# ##### Solution 1: Use Decimal Degrees Precision of Coordinates

# %%
# # These are the cases that actually happen right *at* the service centers
# service_centers_cases = engine_faults_diag[ 
#     ((engine_faults_diag['latitude'] == 36.0666667) & (engine_faults_diag['longitude'] == -86.43472222)) |
#     ((engine_faults_diag['latitude'] == 35.5883333) & (engine_faults_diag['longitude'] == -86.4438888)) |
#     ((engine_faults_diag['latitude'] == 36.1950) & (engine_faults_diag['longitude'] == -83.174722))
# ]

# # Results Excluded: 30

# %%
# display(service_centers_cases.shape)
# display(service_centers_cases.head())

# %% [markdown]
# Since `precision==0.0001` is the same as locating a building, we don't get enough *vicinity* using that so we will skip this precision

# %%
# # These are the cases that happen *at* or within the vicinity of the centers
# # +/- .001 swing and truncate on each lat long. 
# # Precision: +/- 0.062 miles ~= +/- 328 feet ~= +/- 100 meters
# service_centers_vicinity_cases = engine_faults_diag[ 
#     ((engine_faults_diag['latitude'].between(36.065, 36.067, inclusive=True)) & (engine_faults_diag['longitude'].between(-86.435, -86.433, inclusive=True))) |
#     ((engine_faults_diag['latitude'].between(35.587, 35.589, inclusive=True)) & (engine_faults_diag['longitude'].between(-86.444, -86.442, inclusive=True))) |
#     ((engine_faults_diag['latitude'].between(36.194, 36.196, inclusive=True)) & (engine_faults_diag['longitude'].between(-83.175, -83.173, inclusive=True)))
# ]

# # Result Excluded: 36,454
# # Final Remaining: 570,882

# %%
# # These are the cases that happen *at* or within the vicinity of the centers
# # +/- .01 swing and truncate on each lat long. 
# # Precision: +/- 0.62 miles ~= 1091 yard ~= +/- 1 Km
# service_centers_vicinity_cases = engine_faults_diag[ 
#     ((engine_faults_diag['latitude'].between(36.05, 36.07, inclusive=True)) & (engine_faults_diag['longitude'].between(-86.44, -86.42, inclusive=True))) |
#     ((engine_faults_diag['latitude'].between(35.57, 35.59, inclusive=True)) & (engine_faults_diag['longitude'].between(-86.45, -86.43, inclusive=True))) |
#     ((engine_faults_diag['latitude'].between(36.18, 36.20, inclusive=True)) & (engine_faults_diag['longitude'].between(-83.18, -83.16, inclusive=True)))
# ]

# # Result Excluded: 59,570
# # Final Remaining: 547,766

# %%
# display(service_centers_vicinity_cases.shape)
# display(service_centers_vicinity_cases.head())

# %% [markdown]
# ##### Solution 2: Use Haversine method (with numpy)

# %%
# https://www.geeksforgeeks.org/program-distance-two-points-earth/
# Python 3 program to calculate Distance Between Two Points on Earth
from math import radians, cos, sin, asin, sqrt

def get_distance_in_km(lats1, longs1, lats2, longs2):
    """Takes a np.array of coordinates and calculate the distance between 2 coordinates in Km using the Harvesine method"""
     
    # The numpy library contains a function named np.radians() 
    # which converts an array of floats from degrees to radians.
    lats1 = np.radians(lats1)
    lats2 = np.radians(lats2)
    longs1 = np.radians(longs1)
    longs2 = np.radians(longs2)
      
    # Apply Haversine formula
    delta_longs = longs2 - longs1
    delta_lats = lats2 - lats1
    a = np.sin(delta_lats / 2)**2 + np.cos(lats1) * np.cos(lats2) * np.sin(delta_longs / 2)**2
 
    c = 2 * np.arcsin(np.sqrt(a))
    
    # Radius of earth in kilometers. Use 3956 for miles
    r = 6371
      
    # calculate the result
    return(c * r)

# %% [markdown]
# We can now apply this on the dataset, but we need to make some adjustments first

# %%
# Add the coordinates of the service stations to the dataset
engine_faults_diag['svc_ctr_1_lat'] = 36.0666667
engine_faults_diag['svc_ctr_1_long'] = -86.43472222
engine_faults_diag['svc_ctr_2_lat'] = 35.5883333
engine_faults_diag['svc_ctr_2_long'] = -86.4438888
engine_faults_diag['svc_ctr_3_lat'] = 36.1950
engine_faults_diag['svc_ctr_3_long'] = -83.174722

# %%
# Add the distance away of the truck's location from each service center 1, 2, and 3
engine_faults_diag["km_from_svcctr_1"] = get_distance_in_km(engine_faults_diag["latitude"], engine_faults_diag["longitude"], engine_faults_diag["svc_ctr_1_lat"], engine_faults_diag["svc_ctr_1_long"])
engine_faults_diag["km_from_svcctr_2"] = get_distance_in_km(engine_faults_diag["latitude"], engine_faults_diag["longitude"], engine_faults_diag["svc_ctr_2_lat"], engine_faults_diag["svc_ctr_2_long"])
engine_faults_diag["km_from_svcctr_3"] = get_distance_in_km(engine_faults_diag["latitude"], engine_faults_diag["longitude"], engine_faults_diag["svc_ctr_3_lat"], engine_faults_diag["svc_ctr_3_long"])

# %%
# Let's see what those did
display(engine_faults_diag.shape)
display(engine_faults_diag.head())
# Out:
# (607336, 51)
#   record_id  ess_id     event_timestamp  \
# 0         1  990349 2015-02-21 10:47:13
# 1         2  990360 2015-02-21 11:34:34
# 3         4  990370 2015-02-21 11:35:33
# 5         6  990431 2015-02-21 11:40:22
# 6         7  990439 2015-02-21 11:40:52
#
#                          event_description  \
# 0  Low (Severity Low) Engine Coolant Level
# 1                                      nan
# 3      Incorrect Data Steering Wheel Angle
# 5  Low (Severity Low) Engine Coolant Level
# 6  Low (Severity Low) Engine Coolant Level
#
#                               ecu_software_version ecu_serial_number  \
# 0                                          unknown           unknown
# 1                                          unknown           unknown
# 3                                          unknown           unknown
# 5  04993120*00025921*082113134117*07700053*I0*BBZ*          79466580
# 6                                          unknown           unknown
#
#            ecu_model ecu_make ecu_source   spn fmi  active  \
# 0            unknown  unknown          0   111  17    True
# 1            unknown  unknown         11   629  12    True
# 3            unknown  unknown         11  1807   2    True
# 5  6X1u10D1500000000    CMMNS          0   111  17    True
# 6            unknown  unknown          0   111  17    True
#
#    active_transition_count equipment_id mct_number   latitude  longitude  \
# 0                        2         1439  105354361  38.857638 -84.626851
# 1                      127         1439  105354361  38.857638 -84.626851
# 3                      127         1369  105336226  41.421018 -87.767361
# 5                        1         1417  105438630  33.043564 -96.179722
# 6                        2         1597  105344243  36.902916 -86.436481
#
#    location_timestamp  accelerator_pedal  barometric_pressure  \
# 0 2015-02-21 11:34:25                0.0              14.2100
# 1 2015-02-21 11:35:10                NaN                  NaN
# 3 2015-02-21 11:36:08                NaN                  NaN
# 5 2015-02-21 11:40:59               48.0              14.4275
# 6 2015-02-21 11:41:29               82.8              14.2825
#
#    cruise_control_active  cruise_control_set_speed  distance_ltd  \
# 0                   True                  66.48672      423178.7
# 1                   True                       NaN           NaN
# 3                   True                       NaN           NaN
# 5                   True                  64.62260      470381.4
# 6                   True                  64.62260      278736.7
#
#    engine_coolant_temperature  engine_load  engine_oil_pressure  \
# 0                       100.4         11.0                 0.00
# 1                         NaN          NaN                  NaN
# 3                         NaN          NaN                  NaN
# 5                       181.4         30.0                38.28
# 6                       188.6         80.0                39.44
#
#    engine_oil_temperature  engine_rpm  engine_time_ltd  fuel_level  \
# 0                96.74375       0.000           1632.2        43.2
# 1                     NaN         NaN              NaN         NaN
# 3                     NaN         NaN              NaN         NaN
# 5               196.53130    1514.500           9480.0        44.0
# 6               210.03130    1711.375           6292.2        64.8
#
#        fuel_ltd  fuel_rate  fuel_temperature  ign_status  \
# 0  12300.907429   0.000000               NaN        True
# 1           NaN        NaN               NaN        True
# 3           NaN        NaN               NaN        True
# 5  70349.809964   4.583399               NaN        True
# 6  40961.065437  14.291750               NaN        True
#
#    intake_manifold_temperature lamp_status  parking_brake  service_distance  \
# 0                         78.8        1023           True               NaN
# 1                          NaN        1279           True               NaN
# 3                          NaN        1279           True               NaN
# 5                        111.2        1023           True               NaN
# 6                         78.8        1023           True               NaN
#
#       speed  switched_battery_voltage  throttle  turbo_boost_pressure  \
# 0   0.00000                   3276.75       NaN                  0.00
# 1       NaN                       NaN       NaN                   NaN
# 3       NaN                       NaN       NaN                   NaN
# 5  13.60220                   3276.75       NaN                  6.67
# 6  41.53478                   3276.75       NaN                 20.59
#
#    svc_ctr_1_lat  svc_ctr_1_long  svc_ctr_2_lat  svc_ctr_2_long  \
# 0      36.066667      -86.434722      35.588333      -86.443889
# 1      36.066667      -86.434722      35.588333      -86.443889
# 3      36.066667      -86.434722      35.588333      -86.443889
# 5      36.066667      -86.434722      35.588333      -86.443889
# 6      36.066667      -86.434722      35.588333      -86.443889
#
#    svc_ctr_3_lat  svc_ctr_3_long  km_from_svcctr_1  km_from_svcctr_2  \
# 0         36.195      -83.174722        348.939160        397.515424
# 1         36.195      -83.174722        348.939160        397.515424
# 3         36.195      -83.174722        606.467083        658.684856
# 5         36.195      -83.174722        953.079295        937.355204
# 6         36.195      -83.174722         92.986813        146.176436
#
#    km_from_svcctr_3
# 0        322.565735
# 1        322.565735
# 3        704.052410
# 5       1239.429781
# 6        301.794948

# %% [markdown]
# Now, let's define what *Vicinity* means in terms of Km-away from the service centers

# %%
# We will define "in vicinity" as within 1 Km radius
vicinity_limit = 1   # 1 Km = 0.621371 Miles

# %% [markdown]
# - This means that any truck within 1 Km radius of the service stations should be removed
# - We need to consider all 3 service locations

# %%
# These are the cases that happen *at* or within the vicinity of the centers: 1Km Radius
service_centers_vicinity_cases = engine_faults_diag[
    (engine_faults_diag["km_from_svcctr_1"] <= vicinity_limit) |
    (engine_faults_diag["km_from_svcctr_2"] <= vicinity_limit) |
    (engine_faults_diag["km_from_svcctr_3"] <= vicinity_limit)
]

# # Results Excluded: 60,232
# # Final Remaining: 547,104

# %%
display(service_centers_vicinity_cases.shape)
display(service_centers_vicinity_cases.head())
# Out:
# (60232, 51)
#    record_id  ess_id     event_timestamp  \
# 21        22  990567 2015-02-21 11:47:15
# 22        23  990568 2015-02-21 11:47:15
# 24        25  990611 2015-02-21 11:50:50
# 33        34  990769 2015-02-21 12:00:31
# 39        40  990838 2015-02-21 11:42:58
#
#                           event_description  \
# 21                                      nan
# 22                                      nan
# 24  Low (Severity Low) Engine Coolant Level
# 33  Low (Severity Low) Engine Coolant Level
# 39                                      nan
#
#                                ecu_software_version ecu_serial_number  \
# 21                                          unknown           unknown
# 22                                          unknown           unknown
# 24  04993120*00190040*082113134117*07700053*I0*BBZ*          79620774
# 33  04993120*00028430*082113134117*07700053*I0*BBZ*          79465200
# 39                                          unknown           unknown
#
#             ecu_model ecu_make ecu_source   spn fmi  active  \
# 21            unknown  unknown          0  5396   1    True
# 22            unknown  unknown          0  5444   1    True
# 24  6X1u10D1500000000    CMMNS          0   111  17    True
# 33  6X1u10D1500000000    CMMNS          0   111  17    True
# 39            unknown  unknown         11     0   0    True
#
#     active_transition_count equipment_id mct_number   latitude  longitude  \
# 21                      126          302  105435601  36.066574 -86.432962
# 22                      126          302  105435601  36.066574 -86.432962
# 24                        1         1590  105365537  35.587731 -86.444351
# 33                        1         1404  105356055  36.194444 -83.174537
# 39                      127         1620  105416411  36.066527 -86.434120
#
#     location_timestamp  accelerator_pedal  barometric_pressure  \
# 21 2015-02-21 11:48:57                NaN                  NaN
# 22 2015-02-21 11:48:57                NaN                  NaN
# 24 2015-02-21 11:51:25               31.2                14.21
# 33 2015-02-21 12:01:08                NaN                14.21
# 39 2015-02-21 12:05:46                NaN                  NaN
#
#     cruise_control_active  cruise_control_set_speed  distance_ltd  \
# 21                   True                       NaN           NaN
# 22                   True                       NaN           NaN
# 24                   True                  60.89438      244297.7
# 33                   True                  37.28227      363530.9
# 39                   True                       NaN           NaN
#
#     engine_coolant_temperature  engine_load  engine_oil_pressure  \
# 21                         NaN          NaN                  NaN
# 22                         NaN          NaN                  NaN
# 24                       149.0         14.0                42.34
# 33                        68.0         30.0                40.02
# 39                         NaN          NaN                  NaN
#
#     engine_oil_temperature  engine_rpm  engine_time_ltd  fuel_level  \
# 21                     NaN         NaN              NaN         NaN
# 22                     NaN         NaN              NaN         NaN
# 24                169.5313    1220.375           5135.1        34.8
# 33                 70.0250     649.750           8570.1        20.0
# 39                     NaN         NaN              NaN         NaN
#
#         fuel_ltd  fuel_rate  fuel_temperature  ign_status  \
# 21           NaN        NaN               NaN        True
# 22           NaN        NaN               NaN        True
# 24  35476.061121   2.364347               NaN        True
# 33  55447.732424   1.320864               NaN        True
# 39           NaN        NaN               NaN        True
#
#     intake_manifold_temperature lamp_status  parking_brake  service_distance  \
# 21                          NaN       17407           True               NaN
# 22                          NaN       17407           True               NaN
# 24                         77.0        1023           True               NaN
# 33                         48.2        2047           True               NaN
# 39                          NaN         255           True               NaN
#
#        speed  switched_battery_voltage  throttle  turbo_boost_pressure  \
# 21       NaN                       NaN       NaN                   NaN
# 22       NaN                       NaN       NaN                   NaN
# 24  7.990445                   3276.75       NaN                  3.48
# 33  1.970912                   3276.75       NaN                  0.29
# 39       NaN                       NaN       NaN                   NaN
#
#     svc_ctr_1_lat  svc_ctr_1_long  svc_ctr_2_lat  svc_ctr_2_long  \
# 21      36.066667      -86.434722      35.588333      -86.443889
# 22      36.066667      -86.434722      35.588333      -86.443889
# 24      36.066667      -86.434722      35.588333      -86.443889
# 33      36.066667      -86.434722      35.588333      -86.443889
# 39      36.066667      -86.434722      35.588333      -86.443889
#
#     svc_ctr_3_lat  svc_ctr_3_long  km_from_svcctr_1  km_from_svcctr_2  \
# 21         36.195      -83.174722          0.158548         53.187063
# 22         36.195      -83.174722          0.158548         53.187063
# 24         36.195      -83.174722         53.262295          0.078944
# 33         36.195      -83.174722        293.126011        302.107128
# 39         36.195      -83.174722          0.056314         53.180006
#
#     km_from_svcctr_3
# 21        292.954185
# 22        292.954185
# 24        302.160294
# 33          0.064014
# 39        293.058388

# %% [markdown]
# ##### Finally, dropping the vicinity cases

# %% [markdown]
# We need to drop the `service_centers_vicinity_cases` from the `engine_faults_diag`

# %%
engine_faults_diag = engine_faults_diag.drop(service_centers_vicinity_cases.index, axis=0)

# %%
# Check where we are
display(engine_faults_diag.shape)
display(engine_faults_diag.head())
# Out:
# (547104, 51)
#   record_id  ess_id     event_timestamp  \
# 0         1  990349 2015-02-21 10:47:13
# 1         2  990360 2015-02-21 11:34:34
# 3         4  990370 2015-02-21 11:35:33
# 5         6  990431 2015-02-21 11:40:22
# 6         7  990439 2015-02-21 11:40:52
#
#                          event_description  \
# 0  Low (Severity Low) Engine Coolant Level
# 1                                      nan
# 3      Incorrect Data Steering Wheel Angle
# 5  Low (Severity Low) Engine Coolant Level
# 6  Low (Severity Low) Engine Coolant Level
#
#                               ecu_software_version ecu_serial_number  \
# 0                                          unknown           unknown
# 1                                          unknown           unknown
# 3                                          unknown           unknown
# 5  04993120*00025921*082113134117*07700053*I0*BBZ*          79466580
# 6                                          unknown           unknown
#
#            ecu_model ecu_make ecu_source   spn fmi  active  \
# 0            unknown  unknown          0   111  17    True
# 1            unknown  unknown         11   629  12    True
# 3            unknown  unknown         11  1807   2    True
# 5  6X1u10D1500000000    CMMNS          0   111  17    True
# 6            unknown  unknown          0   111  17    True
#
#    active_transition_count equipment_id mct_number   latitude  longitude  \
# 0                        2         1439  105354361  38.857638 -84.626851
# 1                      127         1439  105354361  38.857638 -84.626851
# 3                      127         1369  105336226  41.421018 -87.767361
# 5                        1         1417  105438630  33.043564 -96.179722
# 6                        2         1597  105344243  36.902916 -86.436481
#
#    location_timestamp  accelerator_pedal  barometric_pressure  \
# 0 2015-02-21 11:34:25                0.0              14.2100
# 1 2015-02-21 11:35:10                NaN                  NaN
# 3 2015-02-21 11:36:08                NaN                  NaN
# 5 2015-02-21 11:40:59               48.0              14.4275
# 6 2015-02-21 11:41:29               82.8              14.2825
#
#    cruise_control_active  cruise_control_set_speed  distance_ltd  \
# 0                   True                  66.48672      423178.7
# 1                   True                       NaN           NaN
# 3                   True                       NaN           NaN
# 5                   True                  64.62260      470381.4
# 6                   True                  64.62260      278736.7
#
#    engine_coolant_temperature  engine_load  engine_oil_pressure  \
# 0                       100.4         11.0                 0.00
# 1                         NaN          NaN                  NaN
# 3                         NaN          NaN                  NaN
# 5                       181.4         30.0                38.28
# 6                       188.6         80.0                39.44
#
#    engine_oil_temperature  engine_rpm  engine_time_ltd  fuel_level  \
# 0                96.74375       0.000           1632.2        43.2
# 1                     NaN         NaN              NaN         NaN
# 3                     NaN         NaN              NaN         NaN
# 5               196.53130    1514.500           9480.0        44.0
# 6               210.03130    1711.375           6292.2        64.8
#
#        fuel_ltd  fuel_rate  fuel_temperature  ign_status  \
# 0  12300.907429   0.000000               NaN        True
# 1           NaN        NaN               NaN        True
# 3           NaN        NaN               NaN        True
# 5  70349.809964   4.583399               NaN        True
# 6  40961.065437  14.291750               NaN        True
#
#    intake_manifold_temperature lamp_status  parking_brake  service_distance  \
# 0                         78.8        1023           True               NaN
# 1                          NaN        1279           True               NaN
# 3                          NaN        1279           True               NaN
# 5                        111.2        1023           True               NaN
# 6                         78.8        1023           True               NaN
#
#       speed  switched_battery_voltage  throttle  turbo_boost_pressure  \
# 0   0.00000                   3276.75       NaN                  0.00
# 1       NaN                       NaN       NaN                   NaN
# 3       NaN                       NaN       NaN                   NaN
# 5  13.60220                   3276.75       NaN                  6.67
# 6  41.53478                   3276.75       NaN                 20.59
#
#    svc_ctr_1_lat  svc_ctr_1_long  svc_ctr_2_lat  svc_ctr_2_long  \
# 0      36.066667      -86.434722      35.588333      -86.443889
# 1      36.066667      -86.434722      35.588333      -86.443889
# 3      36.066667      -86.434722      35.588333      -86.443889
# 5      36.066667      -86.434722      35.588333      -86.443889
# 6      36.066667      -86.434722      35.588333      -86.443889
#
#    svc_ctr_3_lat  svc_ctr_3_long  km_from_svcctr_1  km_from_svcctr_2  \
# 0         36.195      -83.174722        348.939160        397.515424
# 1         36.195      -83.174722        348.939160        397.515424
# 3         36.195      -83.174722        606.467083        658.684856
# 5         36.195      -83.174722        953.079295        937.355204
# 6         36.195      -83.174722         92.986813        146.176436
#
#    km_from_svcctr_3
# 0        322.565735
# 1        322.565735
# 3        704.052410
# 5       1239.429781
# 6        301.794948

# %% [markdown]
# #### Only focus on trucks that were involved in `spn == 1569` or `spn == 5246`

# %% [markdown]
# - It is possible that the trucks were involved in different `spn` prior to those codes
# - Could that be a precursor of half- and/or full-derates?
# - So instead of filtering for only these `spn`, what we want to do is focus on all the history of any trucks who were involved in these `spn`
#   - They might have had different `spn` prior to these 2 `spn`

# %%
# Get all the cases that are half- or full-derates
all_derates_cases = engine_faults_diag[engine_faults_diag["spn"].isin(["1569", "5246"])]

# %%
display(all_derates_cases.shape)
display(all_derates_cases.head())
# Out:
# (5543, 51)
#      record_id   ess_id     event_timestamp  \
# 40          41   990856 2015-02-21 12:06:22
# 290        291   994045 2015-02-21 15:35:45
# 340        341   994680 2015-02-21 16:22:24
# 378        379   995223 2015-02-21 17:08:02
# 1580      1581  1001939 2015-02-22 11:14:23
#
#                                      event_description  \
# 40    Condition Exists Engine Protection Torque Derate
# 290   Condition Exists Engine Protection Torque Derate
# 340   Condition Exists Engine Protection Torque Derate
# 378   Condition Exists Engine Protection Torque Derate
# 1580  Condition Exists Engine Protection Torque Derate
#
#                                  ecu_software_version ecu_serial_number  \
# 40    05317106*04047493*092613211021*09300006*G1*BDR*          79723635
# 290   05317106*04047493*092613211021*09300006*G1*BDR*          79723635
# 340   05317106*04047493*092613211021*09300006*G1*BDR*          79723635
# 378   05317106*04047493*092613211021*09300006*G1*BDR*          79723635
# 1580                                          unknown           unknown
#
#               ecu_model ecu_make ecu_source   spn fmi  active  \
# 40    6X1u13D1500000000    CMMNS          0  1569  31    True
# 290   6X1u13D1500000000    CMMNS          0  1569  31    True
# 340   6X1u13D1500000000    CMMNS          0  1569  31    True
# 378   6X1u13D1500000000    CMMNS          0  1569  31    True
# 1580            unknown  unknown          0  1569  31    True
#
#       active_transition_count equipment_id mct_number   latitude  longitude  \
# 40                          5         1721  105439606  39.051805 -84.560509
# 290                         6         1721  105439606  37.735185 -85.808101
# 340                         7         1721  105439606  37.166666 -85.964027
# 378                        10         1721  105439606  36.770324 -86.482870
# 1580                        1         1515  105381937  30.376435 -83.299444
#
#       location_timestamp  accelerator_pedal  barometric_pressure  \
# 40   2015-02-21 12:06:57                0.0              14.2100
# 290  2015-02-21 15:36:21               76.4              14.2825
# 340  2015-02-21 16:23:00               20.4              14.2825
# 378  2015-02-21 17:08:37               63.2              14.3550
# 1580 2015-02-22 11:14:58                NaN                  NaN
#
#       cruise_control_active  cruise_control_set_speed  distance_ltd  \
# 40                     True                  66.48672      121095.5
# 290                    True                  66.48672      121233.4
# 340                    True                  66.48672      121274.7
# 378                    True                  66.48672      121319.2
# 1580                   True                       NaN           NaN
#
#       engine_coolant_temperature  engine_load  engine_oil_pressure  \
# 40                         174.2          0.0                35.96
# 290                        181.4         77.0                39.44
# 340                        181.4          0.0                37.70
# 378                        177.8         55.0                38.28
# 1580                         NaN          NaN                  NaN
#
#       engine_oil_temperature  engine_rpm  engine_time_ltd  fuel_level  \
# 40                  220.4375    1048.125          2319.65        54.4
# 290                 221.0000    1561.125          2322.35        57.6
# 340                 213.5750    1122.375          2323.15        55.6
# 378                 218.7500    1274.125          2323.90        54.0
# 1580                     NaN         NaN              NaN         NaN
#
#           fuel_ltd  fuel_rate  fuel_temperature  ign_status  \
# 40    15620.097177   0.000000              32.0        True
# 290   15638.325048  13.248270              32.0        True
# 340   15643.476403   0.026417              32.0        True
# 378   15649.420274   6.960955              32.0        True
# 1580           NaN        NaN               NaN        True
#
#       intake_manifold_temperature lamp_status  parking_brake  \
# 40                           51.8       18431           True
# 290                          91.4       18431           True
# 340                          60.8       18431           True
# 378                          53.6       18431           True
# 1580                          NaN       18431           True
#
#       service_distance     speed  switched_battery_voltage  throttle  \
# 40                 NaN  51.97187                   3276.75       0.0
# 290                NaN  40.73865                   3276.75       0.0
# 340                NaN  55.39912                   3276.75       0.0
# 378                NaN  62.89442                   3276.75       0.0
# 1580               NaN       NaN                       NaN       NaN
#
#       turbo_boost_pressure  svc_ctr_1_lat  svc_ctr_1_long  svc_ctr_2_lat  \
# 40                    0.58      36.066667      -86.434722      35.588333
# 290                  15.66      36.066667      -86.434722      35.588333
# 340                   0.87      36.066667      -86.434722      35.588333
# 378                   2.32      36.066667      -86.434722      35.588333
# 1580                   NaN      36.066667      -86.434722      35.588333
#
#       svc_ctr_2_long  svc_ctr_3_lat  svc_ctr_3_long  km_from_svcctr_1  \
# 40        -86.443889         36.195      -83.174722        370.747874
# 290       -86.443889         36.195      -83.174722        193.715450
# 340       -86.443889         36.195      -83.174722        129.326913
# 378       -86.443889         36.195      -83.174722         78.361637
# 1580      -86.443889         36.195      -83.174722        696.586202
#
#       km_from_svcctr_2  km_from_svcctr_3
# 40          419.560558        340.288134
# 290         245.360699        289.924658
# 340         180.683202        271.174933
# 378         131.477924        302.586487
# 1580        649.418892        647.098563

# %%
# Which unique trucks have had a derate? We can identify this by the equipment ID
all_derates_cases["equipment_id"].unique()
# Out:
# array(['1721', '1515', '1630', '1487', '1499', '1329', '1365', '1419',
#        '1486', '1509', '1492', '1340', '1328', '1430', '1370', '1497',
#        '1350', '1473', '1608', '1606', '1612', '1354', '1493', '1583',
#        '1465', '1789', '1383', '1389', '1501', '1438', '1463', '1514',
#        '1666', '1689', '1692', '1357', '1396', '310', '1602', '1660',
#        '1445', '1431', '1795', '1399', '1494', '1367', '1364', '1452',
#        '1595', '1740', '1366', '1339', '1425', '1358', '1646', '1391',
#        '1428', '1346', '1490', '1562', '1433', '1663', '1417', '1424',
#        '1771', '1790', '1591', '1797', '1596', '1421', '1547', '1444',
#        '1480', '1466', '1457', '1794', '1703', '1626', '1715', '1437',
#        '1453', '1584', '1597', '1610', '1377', '1652', '1517', '1784',
#        '1751', '1786', '1590', '1341', '1382', '1714', '1711', '1369',
#        '1398', '1791', '1772', '1472', '1418', '1645', '1475', '1815',
#        '1806', '1607', '1560', '1450', '1572', '1375', '1368', '1742',
#        '1650', '1443', '1637', '1495', '1587', '1778', '1566', '1670',
#        '1617', '1691', '1573', '1477', '1476', '1395', '305', '1441',
#        '1405', '1577', '1447', '1659', '1408', '1439', '1403', '1458',
#        '1535', '1668', '1814', '1567', '1524', '1373', '1446', '1629',
#        '1730', '1665', '1381', '1551', '1413', '1643', '1508', '1440',
#        '1455', '1844', '1571', '1429', '1491', '1803', '1467', '1378',
#        '1488', '1739', '1448', '1420', '1384', '1683', '304', '1372',
#        '1502', '1582', '1464', '1599', '1712', '1407', '1603', '1644',
#        '1757', '1618', '1604', '1519', '1831', '1631', '1811', '1628',
#        '1818', '1423', '1636', '1555', '1638', '1710', '1823', '1401',
#        '1435', '1808', '1669', '1649', '1579', '1416', '1534', '1575',
#        '1397', '1539', '1510', '1813', '1719', '1601', '1657', '1621',
#        '1651', '1620', '1708', '1592', '1613', '1619', '1925', '1887',
#        '1662', '1640', '1563', '1713', '1557', '1839', '1881', '1833',
#        '1605', '1513', '1639', '1866', '1485', '1581', '1776', '1586',
#        '301', '1661', '1635', '1907', '1853', '1785', '1594', '1859',
#        '1700', '1600', '1963', '1848', '1918', '1561', '1796', '1624',
#        '1549', '1598', '1972', '1706', '1641', '1874', '1940', '1609',
#        '1642', '1506', '1552', '1685', '1946', '1883', '1913', '1920',
#        '1634', '1995', '1512', '1878', '1564', '1686', '1554', '1505',
#        '1802', '1788', '1807', '1688', '1922', '1903', '1681', '1529',
#        '1904', '1615', '1828', '1694', '1559', '1827', '1745', '1842',
#        '1720', '1525', '1970', '1877', '1888', '1989', '1537', '1932',
#        '1521', '1804', '1854', '1696', '1851', '1565', '1981', '1528',
#        '1741', '1980', '1737', '1580', '1924', '1822', '1766', '1812',
#        '1917', '1933', '1817', '1654', '1731', '2017', '2008', '1726',
#        '1717', '1656', '1868', '1543', '1835', '1664', '1880', '1916',
#        '1996', '1912', '1947', '1997', '1736', '1820', '1729', '1864',
#        '1556', '1898', '1884', '1832', '1705', '1585', '1908', '1752',
#        '1623', '1800', '1732', '1725', '1845', '1876', '1576', '1897',
#        '1647', '1931', '1971', '1852', '1697', '1959', '1953', '1787',
#        '1962', '1893', '2015', '2019', '1957', '1593', '1965', '1873',
#        '1911', '1934', '1942', '1982', '1900', '2009', '1948', '1723',
#        '2006', '1956', '2012', '1836', '1935', '307', '1879', '1792',
#        '1865', '1885', '1690', '1793', '1749', '1860', '1894', '1856',
#        '1704', '1614', '1655', '1667', '1632', '1699', '1746', '1687',
#        '1625', '1871', '1750', '1611', '2013', '1939', '1886', '1999',
#        '1819', '1901', '1821', '1847', '1701', '1588', '1838', '1775',
#        '1743', '308', '1952', '1988', '1716', '1862', '2011', '1863',
#        '1622', '2004', '1764', '1905', '1698', '1846', '309', '1798',
#        '1780', '1762', '1979', '2007', '1919', '1966', '1843', '1938',
#        '1744', '1992', '1976', '1926', '2143', '1718', '1899', '2111',
#        '1978', '1763', '1870', '1994', '2027', '1967', '1928', '1921',
#        '1891', '1734', '1945', '1889', '1849', '2010', '306', '1951',
#        '1768', '1781', '1728', '1748', '1964', '1858', '1758', '1958',
#        '2120', '1756', '2209', '1944', '1927', '2005', '1709', '2082',
#        '1914', '2020', '1872', '1975', '1857', '1733', '1961', '1954',
#        '1985', '1824', '1993', '1895', '1906', '2018', '1977', '1834',
#        '1930', '1984', '1949', '1896', '2109', '1950', '1855', '2000',
#        '1986', '1969', '1991', '1782', '1937', '2021', '2002', '2089',
#        '1968', '1869', '1909', '2211', '1829', '302', '1861', '2175'],
#       dtype=object)

# %%
# Which unique trucks have had a derate? We can identify this by the equipment ID
all_derates_cases["equipment_id"].value_counts().to_frame()
# Out:
#       equipment_id
# 1490           201
# 1692           142
# 1505           133
# 1758            99
# 1445            99
# 1444            96
# 1790            94
# 1494            84
# 1607            81
# 1480            80
# 1804            76
# 1636            75
# 1670            72
# 1888            69
# 1645            63
# 1580            62
# 1383            61
# 1473            60
# 1395            60
# 1818            56
# 1587            54
# 1364            52
# 1591            51
# 1711            51
# 1417            49
# 1508            49
# 1564            48
# 1577            46
# 1608            40
# 1778            40
# 1573            40
# 1453            38
# 1966            38
# 1458            34
# 1970            34
# 1730            32
# 1787            32
# 1524            31
# 1853            30
# 1628            30
# 1932            29
# 1447            28
# 1704            28
# 1732            26
# 1450            25
# 1391            24
# 1510            24
# 1751            24
# 1491            24
# 1535            23
# 1908            23
# 1965            23
# 1683            22
# 1843            22
# 1802            22
# 1953            21
# 1691            21
# 1808            21
# 1452            20
# 1946            20
# 1340            19
# 1566            19
# 2008            18
# 1975            18
# 1629            18
# 1982            18
# 1492            18
# 1814            18
# 1788            18
# 1836            17
# 1739            17
# 1694            16
# 1905            16
# 1586            16
# 1463            16
# 1584            16
# %% [markdown]
# We only want to focus on these trucks in the overall dataset

# %%
# Filter `engine_faults_diag` for only those Equipment IDs
engine_faults_diag = engine_faults_diag[engine_faults_diag["equipment_id"].isin(all_derates_cases["equipment_id"].unique())]

# %%
# Check where we are
display(engine_faults_diag.shape)
display(engine_faults_diag.head())

# # Final Remaining: 435,979
# Out:
# (435979, 51)
#   record_id  ess_id     event_timestamp  \
# 0         1  990349 2015-02-21 10:47:13
# 1         2  990360 2015-02-21 11:34:34
# 3         4  990370 2015-02-21 11:35:33
# 5         6  990431 2015-02-21 11:40:22
# 6         7  990439 2015-02-21 11:40:52
#
#                          event_description  \
# 0  Low (Severity Low) Engine Coolant Level
# 1                                      nan
# 3      Incorrect Data Steering Wheel Angle
# 5  Low (Severity Low) Engine Coolant Level
# 6  Low (Severity Low) Engine Coolant Level
#
#                               ecu_software_version ecu_serial_number  \
# 0                                          unknown           unknown
# 1                                          unknown           unknown
# 3                                          unknown           unknown
# 5  04993120*00025921*082113134117*07700053*I0*BBZ*          79466580
# 6                                          unknown           unknown
#
#            ecu_model ecu_make ecu_source   spn fmi  active  \
# 0            unknown  unknown          0   111  17    True
# 1            unknown  unknown         11   629  12    True
# 3            unknown  unknown         11  1807   2    True
# 5  6X1u10D1500000000    CMMNS          0   111  17    True
# 6            unknown  unknown          0   111  17    True
#
#    active_transition_count equipment_id mct_number   latitude  longitude  \
# 0                        2         1439  105354361  38.857638 -84.626851
# 1                      127         1439  105354361  38.857638 -84.626851
# 3                      127         1369  105336226  41.421018 -87.767361
# 5                        1         1417  105438630  33.043564 -96.179722
# 6                        2         1597  105344243  36.902916 -86.436481
#
#    location_timestamp  accelerator_pedal  barometric_pressure  \
# 0 2015-02-21 11:34:25                0.0              14.2100
# 1 2015-02-21 11:35:10                NaN                  NaN
# 3 2015-02-21 11:36:08                NaN                  NaN
# 5 2015-02-21 11:40:59               48.0              14.4275
# 6 2015-02-21 11:41:29               82.8              14.2825
#
#    cruise_control_active  cruise_control_set_speed  distance_ltd  \
# 0                   True                  66.48672      423178.7
# 1                   True                       NaN           NaN
# 3                   True                       NaN           NaN
# 5                   True                  64.62260      470381.4
# 6                   True                  64.62260      278736.7
#
#    engine_coolant_temperature  engine_load  engine_oil_pressure  \
# 0                       100.4         11.0                 0.00
# 1                         NaN          NaN                  NaN
# 3                         NaN          NaN                  NaN
# 5                       181.4         30.0                38.28
# 6                       188.6         80.0                39.44
#
#    engine_oil_temperature  engine_rpm  engine_time_ltd  fuel_level  \
# 0                96.74375       0.000           1632.2        43.2
# 1                     NaN         NaN              NaN         NaN
# 3                     NaN         NaN              NaN         NaN
# 5               196.53130    1514.500           9480.0        44.0
# 6               210.03130    1711.375           6292.2        64.8
#
#        fuel_ltd  fuel_rate  fuel_temperature  ign_status  \
# 0  12300.907429   0.000000               NaN        True
# 1           NaN        NaN               NaN        True
# 3           NaN        NaN               NaN        True
# 5  70349.809964   4.583399               NaN        True
# 6  40961.065437  14.291750               NaN        True
#
#    intake_manifold_temperature lamp_status  parking_brake  service_distance  \
# 255110                                                nan
# 258078                                                nan
# 258501   Condition Exists Engine Protection Torque Derate
# 261039                                                nan
# 262478                                                nan
# 267702                                                nan
# 269415                                                nan
# 270200   Condition Exists Engine Protection Torque Derate
# 270577                                                nan
# 271505                                                nan
# 271531   Condition Exists Engine Protection Torque Derate
# 271591   Condition Exists Engine Protection Torque Derate
# 273185                                                nan
# 273333   Condition Exists Engine Protection Torque Derate
# 273391   Condition Exists Engine Protection Torque Derate
# 273415   Condition Exists Engine Protection Torque Derate
# 274167   Condition Exists Engine Protection Torque Derate
# 274212   Condition Exists Engine Protection Torque Derate
# 274799                                                nan
# 274883   Condition Exists Engine Protection Torque Derate
# 275056   Condition Exists Engine Protection Torque Derate
# 275081   Condition Exists Engine Protection Torque Derate
# 275997                                                nan
# 276002   Condition Exists Engine Protection Torque Derate
# 276062   Condition Exists Engine Protection Torque Derate
# 276197   Condition Exists Engine Protection Torque Derate
# 276246   Condition Exists Engine Protection Torque Derate
# 276254                                                nan
# 276360                                                nan
# 277005   Condition Exists Engine Protection Torque Derate
# 277600                                                nan
# 277786   Condition Exists Engine Protection Torque Derate
# 277837   Condition Exists Engine Protection Torque Derate
# 278371   Condition Exists Engine Protection Torque Derate
# 278515                                                nan
# 279068   Condition Exists Engine Protection Torque Derate
# 279134   Condition Exists Engine Protection Torque Derate
# 279717   Condition Exists Engine Protection Torque Derate
# 279912                                                nan
# 279985   Condition Exists Engine Protection Torque Derate
# 280057   Condition Exists Engine Protection Torque Derate
# 280125   Condition Exists Engine Protection Torque Derate
# 280253   Condition Exists Engine Protection Torque Derate
# 280321   Condition Exists Engine Protection Torque Derate
# 280375   Condition Exists Engine Protection Torque Derate
# 281160   Condition Exists Engine Protection Torque Derate
# 281241   Condition Exists Engine Protection Torque Derate
# 281690                                                nan
# 281795   Condition Exists Engine Protection Torque Derate
# 284606   Condition Exists Engine Protection Torque Derate
# 284841   Condition Exists Engine Protection Torque Derate
# 286057                                                nan
# 286235   Condition Exists Engine Protection Torque Derate
# 286267   Condition Exists Engine Protection Torque Derate
# 286929   Condition Exists Engine Protection Torque Derate
# 286992   Condition Exists Engine Protection Torque Derate
# 287270   Condition Exists Engine Protection Torque Derate
# 287309   Condition Exists Engine Protection Torque Derate
# 287313                                                nan
# 287818   Condition Exists Engine Protection Torque Derate
# 287853   Condition Exists Engine Protection Torque Derate
# 287952                                                nan
# 287970   Condition Exists Engine Protection Torque Derate
# 287997   Condition Exists Engine Protection Torque Derate
# 288016   Condition Exists Engine Protection Torque Derate
# 288258   Condition Exists Engine Protection Torque Derate
# 288284   Condition Exists Engine Protection Torque Derate
# 288316   Condition Exists Engine Protection Torque Derate
# 288339   Condition Exists Engine Protection Torque Derate
# 288455   Condition Exists Engine Protection Torque Derate
# 288482   Condition Exists Engine Protection Torque Derate
# 288660   Condition Exists Engine Protection Torque Derate
# 288883   Condition Exists Engine Protection Torque Derate
# 288905   Condition Exists Engine Protection Torque Derate
# 288919                                                nan
# 289240                                                nan
# 289278   Condition Exists Engine Protection Torque Derate
# 289406   Condition Exists Engine Protection Torque Derate
# 289445   Condition Exists Engine Protection Torque Derate
# 289479   Condition Exists Engine Protection Torque Derate
# 289569                                                nan
# 289575   Condition Exists Engine Protection Torque Derate
# 289579                                                nan
# 291522                                                nan
# 291860   Condition Exists Engine Protection Torque Derate
# 293478                                                nan
# 294840                                                nan
# 295851                                                nan
# 296003   Condition Exists Engine Protection Torque Derate
# 296059   Condition Exists Engine Protection Torque Derate
# 296118   Condition Exists Engine Protection Torque Derate
# 296186   Condition Exists Engine Protection Torque Derate
# 296392   Condition Exists Engine Protection Torque Derate
# 296492   Condition Exists Engine Protection Torque Derate
# 296519   Condition Exists Engine Protection Torque Derate
# 298895   Condition Exists Engine Protection Torque Derate
# 298975   Condition Exists Engine Protection Torque Derate
# 299916   Condition Exists Engine Protection Torque Derate
# 299956   Condition Exists Engine Protection Torque Derate
# 301340                                                nan
# 301451   Condition Exists Engine Protection Torque Derate
# 301519   Condition Exists Engine Protection Torque Derate
# 301796   Condition Exists Engine Protection Torque Derate
# 301841   Condition Exists Engine Protection Torque Derate
# 301813                                                nan
# 302314                                                nan
# 302433   Condition Exists Engine Protection Torque Derate
# 302712   Condition Exists Engine Protection Torque Derate
# 302781   Condition Exists Engine Protection Torque Derate
# 302930   Condition Exists Engine Protection Torque Derate
# 303057   Condition Exists Engine Protection Torque Derate
# 303656   Low Voltage (Engine Intake Manifold #1 Pressure)
# 303777   Condition Exists Engine Protection Torque Derate
# 303875                                                nan
# 303886   Condition Exists Engine Protection Torque Derate
# 303959   Condition Exists Engine Protection Torque Derate
# 304063   Condition Exists Engine Protection Torque Derate
# 304110   Condition Exists Engine Protection Torque Derate
# 304224                                                nan
# 304280   Condition Exists Engine Protection Torque Derate
# 304327   Condition Exists Engine Protection Torque Derate
# 304392                                                nan
# 304405   Condition Exists Engine Protection Torque Derate
# 304448   Condition Exists Engine Protection Torque Derate
# 304764   Condition Exists Engine Protection Torque Derate
# 304833   Condition Exists Engine Protection Torque Derate
# 304875   Condition Exists Engine Protection Torque Derate
# 304908   Condition Exists Engine Protection Torque Derate
# 304957                                                nan
# 305487   Condition Exists Engine Protection Torque Derate
# 305647  High Voltage (Engine Intake Manifold 1 Tempera...
# 306311                                                nan
# 306495   Condition Exists Engine Protection Torque Derate
# 306539   Condition Exists Engine Protection Torque Derate
# 307709                                                nan
# 307766   Condition Exists Engine Protection Torque Derate
# 307829   Condition Exists Engine Protection Torque Derate
# 308160                                                nan
# 308186   Condition Exists Engine Protection Torque Derate
# 311051                                                nan
# 312215                                                nan
# 312586         Low (Severity Medium) Engine Coolant Level
# 312722         Low (Severity Medium) Engine Coolant Level
# 313364         Low (Severity Medium) Engine Coolant Level
# 313381                                                nan
# 313468         Low (Severity Medium) Engine Coolant Level
# 313837         Low (Severity Medium) Engine Coolant Level
# 314309                                                nan
# 314596                                                nan
# 315865                                                nan
# 316707                                                nan
# 320605                                                nan
# 320606         Low (Severity Medium) Engine Coolant Level
# 320683   Condition Exists Engine Protection Torque Derate
# 320688         Low (Severity Medium) Engine Coolant Level
# 320751         Low (Severity Medium) Engine Coolant Level
# 320856         Low (Severity Medium) Engine Coolant Level
# 320962         Low (Severity Medium) Engine Coolant Level
# 321114         Low (Severity Medium) Engine Coolant Level
# 321015         Low (Severity Medium) Engine Coolant Level
# 321200         Low (Severity Medium) Engine Coolant Level
# 321300         Low (Severity Medium) Engine Coolant Level
# 321373         Low (Severity Medium) Engine Coolant Level
# 321470         Low (Severity Medium) Engine Coolant Level
# 321426         Low (Severity Medium) Engine Coolant Level
# 321523         Low (Severity Medium) Engine Coolant Level
# 322196         Low (Severity Medium) Engine Coolant Level
# 322277         Low (Severity Medium) Engine Coolant Level
# 322345         Low (Severity Medium) Engine Coolant Level
# 322412         Low (Severity Medium) Engine Coolant Level
# 322464         Low (Severity Medium) Engine Coolant Level
# 322587   Condition Exists Engine Protection Torque Derate
# 322639         Low (Severity Medium) Engine Coolant Level
# 322653   Condition Exists Engine Protection Torque Derate
# 322773   Condition Exists Engine Protection Torque Derate
# 322700         Low (Severity Medium) Engine Coolant Level
# 322781         Low (Severity Medium) Engine Coolant Level
# 322832         Low (Severity Medium) Engine Coolant Level
# 322909         Low (Severity Medium) Engine Coolant Level
# 323660         Low (Severity Medium) Engine Coolant Level
# 323933         Low (Severity Medium) Engine Coolant Level
# 323992         Low (Severity Medium) Engine Coolant Level
# 324021                                                nan
# 324057         Low (Severity Medium) Engine Coolant Level
# 324136         Low (Severity Medium) Engine Coolant Level
# 324331         Low (Severity Medium) Engine Coolant Level
# 324350         Incorrect Data Engine Exhaust Gas Pressure
# 324371                                                nan
# 324377         Low (Severity Medium) Engine Coolant Level
# 325074         Low (Severity Medium) Engine Coolant Level
# 325143         Low (Severity Medium) Engine Coolant Level
# 325210         Low (Severity Medium) Engine Coolant Level
# 325255         Low (Severity Medium) Engine Coolant Level
# 325376         Low (Severity Medium) Engine Coolant Level
# 325422         Low (Severity Medium) Engine Coolant Level
# 325500         Low (Severity Medium) Engine Coolant Level
# 325543         Low (Severity Medium) Engine Coolant Level
# 325598         Low (Severity Medium) Engine Coolant Level
# 325639         Low (Severity Medium) Engine Coolant Level
# 325669         Low (Severity Medium) Engine Coolant Level
# 325698         Low (Severity Medium) Engine Coolant Level
# 325711   Condition Exists Engine Protection Torque Derate
# 326150                                                nan
# 326241                                                nan
# 326501   Condition Exists Engine Protection Torque Derate
# 326524   Condition Exists Engine Protection Torque Derate
# 326550   Condition Exists Engine Protection Torque Derate
# 326581   Condition Exists Engine Protection Torque Derate
# 326994                                                nan
# 328392                                                nan
# 331034                                                nan
# 331207   Condition Exists Engine Protection Torque Derate
# 331285   Condition Exists Engine Protection Torque Derate
# 332837                                                nan
# 333462                                                nan
# 334200                                                nan
# 337757                                                nan
# 339309                                                nan
# 340463                                                nan
# 341636                                                nan
# 344191                                                nan
# 344383   Condition Exists Engine Protection Torque Derate
# 345652   Condition Exists Engine Protection Torque Derate
# 347462                                                nan
# 348509                                                nan
# 352537                                                nan
# 352716                                                nan
# 353934                                                nan
# 357813                                                nan
# 360072                                                nan
# 360375   Condition Exists Engine Protection Torque Derate
# 360743         Incorrect Data Engine Exhaust Gas Pressure
# 361107                                                nan
# 361659                                                nan
# 364204                                                nan
# 369512                                                nan
# 369640   Condition Exists Engine Protection Torque Derate
# 372258                                                nan
# 374056                                                nan
# 375734                                                nan
# 379309                                                nan
# 380818                                                nan
# 380838         Incorrect Data Engine Exhaust Gas Pressure
# 381542                                                nan
# 382534         Incorrect Data Engine Exhaust Gas Pressure
# 386592         Incorrect Data Engine Exhaust Gas Pressure
# 386648  High (Severity Low) Aftertreatment Diesel Part...
# 386671  High (Severity High) Aftertreatment 1 Particul...
# 387399  High (Severity High) Aftertreatment 1 Particul...
# 387515                                                nan
# 387848  High (Severity Medium) Engine Exhaust Gas Pres...
# 388034          Low Voltage (Engine Exhaust Gas Pressure)
# 388101  High (Severity Low) Aftertreatment 1 Particula...
# 388129         Incorrect Data Engine Exhaust Gas Pressure
# 388133  High (Severity Medium) Engine Exhaust Gas Pres...
# 388152         Incorrect Data Engine Exhaust Gas Pressure
# 388876  High (Severity Medium) Engine Exhaust Gas Pres...
# 389450                                                nan
# 390645                                                nan
# 391581                                                nan
# 394498                                                nan
# 403874                                                nan
# 404844                                                nan
# 405759                                                nan
# 408944                                                nan
# 409576                                                nan
# 411963                                                nan
# 416283                                                nan
# 416336   Condition Exists Engine Protection Torque Derate
# 416451   Condition Exists Engine Protection Torque Derate
# 416524   Condition Exists Engine Protection Torque Derate
# 416547   Condition Exists Engine Protection Torque Derate
# 417408                                                nan
# 417499   Condition Exists Engine Protection Torque Derate
# 419656                                                nan
# 420650                                                nan
# 421565                                                nan
# 422322   Condition Exists Engine Protection Torque Derate
# 422402   Condition Exists Engine Protection Torque Derate
# 422465   Condition Exists Engine Protection Torque Derate
# 422566   Condition Exists Engine Protection Torque Derate
# 422608   Condition Exists Engine Protection Torque Derate
# 425296                                                nan
# 429613                                                nan
# 429645   Condition Exists Engine Protection Torque Derate
# 429702   Condition Exists Engine Protection Torque Derate
# 429791   Condition Exists Engine Protection Torque Derate
# 429848   Condition Exists Engine Protection Torque Derate
# 429899   Condition Exists Engine Protection Torque Derate
# 430145   Condition Exists Engine Protection Torque Derate
# 431261                                                nan
# 431869   Condition Exists Engine Protection Torque Derate
# 432110                                                nan
# 432155   Condition Exists Engine Protection Torque Derate
# 432413   Condition Exists Engine Protection Torque Derate
# 432581   Condition Exists Engine Protection Torque Derate
# 432605   Condition Exists Engine Protection Torque Derate
# 432644   Condition Exists Engine Protection Torque Derate
# 433230                                                nan
# 433522   Condition Exists Engine Protection Torque Derate
# 433588   Condition Exists Engine Protection Torque Derate
# 433618   Condition Exists Engine Protection Torque Derate
# 433672   Condition Exists Engine Protection Torque Derate
# 433691   Condition Exists Engine Protection Torque Derate
# 433707   Condition Exists Engine Protection Torque Derate
# 433711                                                nan
# 434026   Condition Exists Engine Protection Torque Derate
# 434049   Condition Exists Engine Protection Torque Derate
# 434177   Condition Exists Engine Protection Torque Derate
# 434196   Condition Exists Engine Protection Torque Derate
# 434471   Condition Exists Engine Protection Torque Derate
# 434623   Condition Exists Engine Protection Torque Derate
# 434719   Condition Exists Engine Protection Torque Derate
# 434751   Condition Exists Engine Protection Torque Derate
# 434775   Condition Exists Engine Protection Torque Derate
# 435282   Condition Exists Engine Protection Torque Derate
# 435500   Condition Exists Engine Protection Torque Derate
# 435510                                                nan
# 436511   Condition Exists Engine Protection Torque Derate
# 436563   Condition Exists Engine Protection Torque Derate
# 436757   Condition Exists Engine Protection Torque Derate
# 436801   Condition Exists Engine Protection Torque Derate
# 436857   Condition Exists Engine Protection Torque Derate
# 436826                                                nan
# 436908   Condition Exists Engine Protection Torque Derate
# 437758   Condition Exists Engine Protection Torque Derate
# 437823   Condition Exists Engine Protection Torque Derate
# 438079   Condition Exists Engine Protection Torque Derate
# 438295                                                nan
# 438296   Condition Exists Engine Protection Torque Derate
# 438351   Condition Exists Engine Protection Torque Derate
# 438859   Condition Exists Engine Protection Torque Derate
# 438915   Condition Exists Engine Protection Torque Derate
# 439018                                                nan
# 439353   Condition Exists Engine Protection Torque Derate
# 439417   Condition Exists Engine Protection Torque Derate
# 439531                                                nan
# 440027                                                nan
# 440105   Condition Exists Engine Protection Torque Derate
# 440167   Condition Exists Engine Protection Torque Derate
# 453605                                                nan
# 454230   Condition Exists Engine Protection Torque Derate
# 454382   Condition Exists Engine Protection Torque Derate
# 454472   Condition Exists Engine Protection Torque Derate
# 454493   Condition Exists Engine Protection Torque Derate
# 454650                                                nan
# 454656   Condition Exists Engine Protection Torque Derate
# 454666                                                nan
# 454751   Condition Exists Engine Protection Torque Derate
# 455569                                                nan
# 455869   Condition Exists Engine Protection Torque Derate
# 455902   Condition Exists Engine Protection Torque Derate
# 456994                                                nan
# 457166   Condition Exists Engine Protection Torque Derate
# 461498                                                nan
# 462356                                                nan
# 462437   Condition Exists Engine Protection Torque Derate
# 463396                                                nan
# 466859                                                nan
# 466888   Condition Exists Engine Protection Torque Derate
# 467024   Condition Exists Engine Protection Torque Derate
# 473924                                                nan
# 486430  Low (Severity Medium) Engine Intake Manifold #...
# 491562   Condition Exists Engine Protection Torque Derate
# 491628   Condition Exists Engine Protection Torque Derate
# 500107  High (Severity Low) Aftertreatment 1 Particula...
# 506400      Incorrect Data Aftertreatment Fuel Injector 1
# 513457                                                nan
# 519513  Out of Calibration Engine Exhaust Gas Recircul...
# 520137  Out of Calibration Engine Exhaust Gas Recircul...
# 520346  High (Severity Medium) Aftertreatment 1 Partic...
# 539316                                                nan
#
#                                    ecu_software_version ecu_serial_number  \
# 2865    04993120*00063662*040213150018*07700044*I0*BBZ*          79488009
# 4361    04993120*00063662*040213150018*07700044*I0*BBZ*          79488009
# 39378   04993120*00063662*040213150018*07700044*I0*BBZ*          79488009
# 54742   04993120*00063662*040213150018*07700044*I0*BBZ*          79488009
# 58293   04993120*00063662*040213150018*07700044*I0*BBZ*          79488009
# 59889   04993120*00063662*040213150018*07700044*I0*BBZ*          79488009
# ...
# 274212        535.703978        247.996464
# 274799        313.288563         70.956574
# 274883        201.941004        101.565250
# 275056        111.640908        319.912224
# 275081        100.526220        358.083394
# 438296        110.078824        247.427204
# 438351        151.052999        223.896037
# 438859        260.853959        238.908140
# 438915        277.195249        245.596637
# 439018        316.138922        205.909915
# 439353        362.967422        193.481074
# 439417        395.359901        228.765406
# 439531        474.053683        310.898209
# 440027        222.027254        268.202201
# 440105        153.677204        224.318318
# 440167        103.850749        250.891513
# 453605        396.952887        574.022552
# 454230        723.858071        766.613892
# 454382        674.987171        714.419073
# 454472        592.721437        628.002569
# 454493        532.843650        561.165106
# 454650        484.919820        501.790887
# 454656        482.453410        498.635162
# 454666        473.084892        486.299794
# 454751        255.657840        290.202919
# 455569        426.902205        345.863639
# 455869        747.923778        632.482624
# 455902        807.986185        693.032256
# 456994        316.205861        333.451192
# 457166        282.642078        305.315063
# 461498        141.570225        302.181666
# 462356        279.112057        230.940544
# 462437        280.193056        222.020661
# 463396         65.434698        264.391440
# 466859        247.365099         55.797852
# 466888        180.345241        128.925970
# 467024        138.696326        362.788762
# 473924        511.644958        212.012173
# 486430        104.699001        313.398026
# 491562        173.375351        274.393654
# 491628        258.578727        290.422546
# 500107        313.830355        328.082498
# 506400        449.923593        566.168264
# 513457        671.611466        374.059340
# 519513        286.890403        299.704388
# 520137        122.199905        266.529754
# 520346         30.716640        289.785048
# 539316        225.108180         77.672752

# %% [markdown]
# - `activeTransitionCount` - Capped out at ~120. Might not be very helpful because it is not incremental
# - `Ltd` - Lifetime-to-date
# - Better to pay more attention to `event_timestamp` than the `location_timestamp`
#   - If you are not doing a lot of lat,long
# - AcceleratorPedal - Might not have a lot of value
#
# **Handling Missing Data**
#
# - Forward Filling: `fill_na()`
# - Interpolating
# - Back-filling

# %% [markdown]
# ## Looking At `service_fault_codes`

# %%
display(service_fault_codes.shape)
display(service_fault_codes.head(5))
display(service_fault_codes.info())

# %% [markdown]
# ### Data Cleanups `service_fault_codes`

# %%
# Rename all columns to format "column_name"
service_fault_codes = service_fault_codes.rename(columns={
    "Published in CES 14602": "published_in_ces14602",
    "Cummins Fault Code": "cummins_fault_code",
    "Revision": "revision",
    "PID": "p_id",
    "SID": "s_id",
    "MID": "m_id",
    "J1587 FMI": "j1587_fmi",
    "SPN": "spn",
    "J1939 FMI": "j1939_fmi",
    "J2012 Pcode": "j2012_pcode",
    "Lamp Color": "lamp_color",
    "Lamp Device": "lamp_device",
    "Cummins Description": "cummins_description",
    "Algorithm Description": "algorithm_description"
})

# %% [markdown]
# - `published_in_ces14602`: `Y` to all 7124
# - `cummins_fault_code`: Each one is a unique fault code
# - `revision`: Only one revision : 167
# - `p_id`: Most are `Not Mapped`
# - `s_id`: Most are `Not Mapped`
# - `m_id`: Most are `Not Mapped`, `0`, or `128`
# - `j1587_fmi`: From `0` to `14`, most are 11
# - `spn`: 1915 rows
# - `j1939_fmi`: From `0` to `31`, most are 31
# - `j2012_pcode`: Most are not mapped
# - `lamp_color`: Most are `Amber`, but also `Maintenance`, `None`, `Red`
# - `lamp_device`: Most are `Warning`, but also `Maintenance`, `None`, `Stop / Shutdown`
# - `cummins_description`: 5374 unique entries
# - `algorithm_description`: 1879 unique entries
